# %% [markdown]
# The <b>mean squared error</b> has increased. So this shows that a single feature is not a good predictor of housing prices.
#
# ** To-Do 1: Make a train-test split and calculate the mean squared error for training data and test data.**
#
# ** To-Do 2: Plot the residuals for training and test datasets**

# %% [markdown]
# **In the next section, we are going to read in a feather file and assemble the dataset in one Pandas dataframe that
# we can work with.**
# Refer to the "explore_questionnaire.pdf" in the folder for detailed explanation of the dataset.
#
# <img src="./w56.png"/>
#
# To install and run feather use:
#
# **pip install feather-format** -- or else, (if you get import error) **pip install feather-format**

# %%
import feather
import numpy
import pandas as pd
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix

# Read feather frames to individual variables

anp_df = feather.read_dataframe('data_science_case/anp.feather')
face_df = feather.read_dataframe('data_science_case/face.feather')
image_df = feather.read_dataframe('data_science_case/image_data.feather')
metrics_df = feather.read_dataframe('data_science_case/image_metrics.feather')
object_labels_df = feather.read_dataframe('data_science_case/object_labels.feather')
survey_df = feather.read_dataframe('data_science_case/survey.feather')

# %%
anp_df.head()
# Out:
#                        image_id      anp_label  anp_sentiment  emotion_score  \
# 0  951727030670259635_143763900       hot_boys          0.017         0.1760
# 1  951727030670259635_143763900   young_couple          0.019         0.2113
# 2  951727030670259635_143763900  dirty_laundry         -0.263         0.0929
# 3  951727030670259635_143763900    global_mall         -0.031         0.1304
# 4  951728575726873168_289794729     high_boots          0.025         0.1394
#
#   emotion_label
# 0     amazement
# 1           joy
# 2           joy
# 3      interest
# 4     amazement

# %%
face_df.head()
# Out:
#                         image_id  face_id face_gender  face_gender_confidence  \
# 0  1003944279371027183_703978203      6.0      Female               98.741425
# 1  1003944279371027183_703978203      6.0      Female               98.741425
# 2  1003944279371027183_703978203      6.0      Female               98.741425
# 3  1003944279371027183_703978203     68.0        Male               99.927521
# 4  1003944279371027183_703978203     68.0        Male               99.927521
#
#    face_age_range_high  face_age_range_low  face_sunglasses  face_beard  \
# 0                 38.0                20.0            False       False
# 1                 38.0                20.0            False       False
# 2                 38.0                20.0            False       False
# 3                 77.0                57.0            False       False
# 4                 77.0                57.0            False       False
#
#    face_beard_confidence  face_mustache  face_mustache_confidence  face_smile  \
# 0              99.998474          False                 99.999794       False
# 1              99.998474          False                 99.999794       False
# 2              99.998474          False                 99.999794       False
# 3              99.981598          False                 99.993256       False
# 4              99.981598          False                 99.993256       False
#
#    face_smile_confidence  eyeglasses  eyeglasses_confidence   face_emo  \
# 0              99.916168        True              95.395546        SAD
# 1              99.916168        True              95.395546       CALM
# 2              99.916168        True              95.395546  SURPRISED
# 3              84.395294        True              99.420914      HAPPY
# 4              84.395294        True              99.420914        SAD
#
#    emo_confidence
# 0       12.660271
# 1        8.252973
# 2       24.634266
# 3       53.603287
# 4        5.509090

# %%
image_df.head()
# Out:
#                          image_id                                image_link  \
# 0  1316962883971761394_3468175004  https://www.instagram.com/p/BJGysPxgsTy/
# 1    552382455733335946_263042348   https://www.instagram.com/p/eqdOq2JLeK/
# 2    594552614686078174_263042348   https://www.instagram.com/p/hARnP2pLTe/
# 3    553884883234370621_263042348   https://www.instagram.com/p/evy13fpLQ9/
# 4    725551583154452417_263042348   https://www.instagram.com/p/oRrVIcJLfB/
#
#                                            image_url  image_height  \
# 0  https://scontent.cdninstagram.com/t51.2885-15/...         640.0
# 1  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 2  https://scontent.cdninstagram.com/t51.2885-15/...         640.0
# 3  https://scontent.cdninstagram.com/t51.2885-15/...         640.0
# 4  https://scontent.cdninstagram.com/t51.2885-15/...         640.0
#
#    image_width image_filter image_posted_time_unix    image_posted_time  \
# 0        640.0        Lo-fi             1471214231  14-08-2016 22:37:11
# 1        612.0       Normal             1380069141  25-09-2013 00:32:21
# 2        640.0       Vesper             1385096216  22-11-2013 04:56:56
# 3        640.0        Amaro             1380248245  27-09-2013 02:17:25
# 4        640.0        Amaro             1400712510  21-05-2014 22:48:30
#
#    data_memorability     user_id   user_full_name       user_name  \
# 0           0.800521  3468175004     Leah Jenkins     leah.chelle
# 1           0.875568   263042348  Taylor Degruise  taylordegruise
# 2           0.672679   263042348  Taylor Degruise  taylordegruise
# 3           0.843525   263042348  Taylor Degruise  taylordegruise
# 4           0.859796   263042348  Taylor Degruise  taylordegruise
#
#   user_website                                   user_profile_pic user_bio  \
# 0               https://scontent.cdninstagram.com/t51.2885-19/...
# 1               https://scontent.cdninstagram.com/t51.2885-19/...
# 2               https://scontent.cdninstagram.com/t51.2885-19/...
# 3               https://scontent.cdninstagram.com/t51.2885-19/...
# 4               https://scontent.cdninstagram.com/t51.2885-19/...
#
#    user_followed_by  user_follows  user_posted_photos
# 0               7.0           0.0                 1.0
# 1             316.0         347.0                73.0
# 2             316.0         347.0                73.0
# 3             316.0         347.0                73.0
# 4             316.0         347.0                73.0

# %%
metrics_df.head()
# Out:
#                          image_id  comment_count comment_count_time_created  \
# 0  1337283311810249709_3041716852            0.0        19-06-2017 19:33:26
# 1  1337283311810249709_3041716852            0.0        19-06-2017 19:23:26
# 2  1337834353379743556_3041716852            0.0        19-06-2017 19:33:26
# 3  1337834353379743556_3041716852            0.0        19-06-2017 19:23:26
# 4  1516356155708878303_3041716852            5.0        19-06-2017 19:23:07
#
#    like_count like_count_time_created
# 0        15.0     19-06-2017 19:23:26
# 1        15.0     19-06-2017 19:23:26
# 2        23.0     19-06-2017 19:23:26
# 3        23.0     19-06-2017 19:23:26
# 4        19.0     19-06-2017 19:23:07

# %%
object_labels_df.head()
# Out:
#                         image_id data_amz_label  data_amz_label_confidence
# 0   863479386465416946_545497348         Animal                  90.163101
# 1   916939688871507178_545497348         Animal                  83.518669
# 2   551681403589539797_545497348         Animal                  74.837212
# 3  1189285646274180856_545497348         Animal                  76.920967
# 4   962361211517974133_545497348         Animal                  71.223869

# %%
survey_df.head()
# Out:
#                                  id  gender  born             education  \
# 0  920bf027f7d13dbdc7b66b3d3324903c    Male  1975      College graduate
# 1  b433b2bfe49e28d0b7c45925b53084e0    Male  1978      College graduate
# 2  4becd8768d42ffa6ef0a17d827f230a2    Male  1980  High school graduate
# 3  01d90eeb34866d03c52925738da7865f    Male  1959      College graduate
# 4  f4f54676f75f47c17dc434cf68845328  Female  1990  High school graduate
#
#              employed              income  A_2  N_1  P_1  E_1  \
# 0  Employed for wages  $30,000 to $39,999    4    5    5    3
# 1  Employed for wages  $20,000 to $29,999    8    0    9    7
# 2       Self-employed  $40,000 to $49,999    7    7    6    9
# 3  Employed for wages  $10,000 to $19,999    6    4    1    5
# 4  Employed for wages  $80,000 to $89,999    7    3    8    7
#
#         ...         P    E    R    M    A  PERMA  N_EMO  P_EMO  imagecount  \
# 0       ...         5  3.0  6.0  6.0  4.0      5    5.0      5       465.0
# 1       ...         9  7.0  9.0  8.0  7.0      9    0.0      9         6.0
# 2       ...         6  9.0  6.0  6.0  8.0      6    7.0      6         NaN
# 3       ...         1  5.0  3.0  3.0  3.0      1    4.0      1         NaN
# 4       ...         8  7.0  8.0  8.0  7.0      8    3.0      8       767.0
#
#    private_account
# 0           public
# 1           public
# 2          private
# 3          private
# 4           public
#
# [5 rows x 45 columns]

# %%
list(survey_df)
# Out:
# [u'id',
#  u'gender',
#  u'born',
#  u'education',
#  u'employed',
#  u'income',
#  u'A_2',
#  u'N_1',
#  u'P_1',
#  u'E_1',
#  u'A_1',
#  u'H_1',
#  u'M_1',
#  u'R_1',
#  u'M_2',
#  u'E_2',
#  u'LON',
#  u'H_2',
#  u'P_2',
#  u'N_2',
#  u'A_3',
#  u'N_3',
#  u'E_3',
#  u'H_3',
#  u'R_2',
#  u'M_3',
#  u'R_3',
#  u'P_3',
#  u'HAP',
#  u'participate',
#  u'insta_user_id',
#  u'completed',
#  u'start_q',
#  u'end_q',
#  u'network_id',
#  u'P',
#  u'E',
#  u'R',
#  u'M',
#  u'A',
#  u'PERMA',
#  u'N_EMO',
#  u'P_EMO',
#  u'imagecount',
#  u'private_account']

# %%
print survey_df['start_q'].max()
print survey_df['start_q'].min()
print survey_df['end_q'].max()
print survey_df['end_q'].min()
# Out:
# 2017-03-23 15:11:19
# 2016-12-05 14:01:21
# 2017-03-23 15:16:17
# 2016-12-05 14:02:52

# %% [markdown]
# # Merging of the Image elements

# %%
# Merge them based on the image_id so that we have a large data frame containing all the elements

image_anp_frame = pd.merge(image_df, anp_df, how='inner', on='image_id')
im_anp_obj_frame = pd.merge(image_anp_frame, object_labels_df, how='inner', on='image_id')
im_anp_obj_face_frame = pd.merge(im_anp_obj_frame, face_df, how='inner', on='image_id')

# %%
im_anp_obj_face_frame.shape
# Out:
# (3887625, 40)

# %%
im_anp_obj_face_frame.head()
# Out:
#                        image_id                               image_link  \
# 0  552382455733335946_263042348  https://www.instagram.com/p/eqdOq2JLeK/
# 1  552382455733335946_263042348  https://www.instagram.com/p/eqdOq2JLeK/
# 2  552382455733335946_263042348  https://www.instagram.com/p/eqdOq2JLeK/
# 3  552382455733335946_263042348  https://www.instagram.com/p/eqdOq2JLeK/
# 4  552382455733335946_263042348  https://www.instagram.com/p/eqdOq2JLeK/
#
#                                            image_url  image_height  \
# 0  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 1  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 2  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 3  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 4  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
#
#    image_width image_filter image_posted_time_unix    image_posted_time  \
# 0        612.0       Normal             1380069141  25-09-2013 00:32:21
# 1        612.0       Normal             1380069141  25-09-2013 00:32:21
# 2        612.0       Normal             1380069141  25-09-2013 00:32:21
# 3        612.0       Normal             1380069141  25-09-2013 00:32:21
# 4        612.0       Normal             1380069141  25-09-2013 00:32:21
#
#    data_memorability    user_id       ...       face_beard  \
# 0           0.875568  263042348       ...            False
# 1           0.875568  263042348       ...            False
# 2           0.875568  263042348       ...            False
# 3           0.875568  263042348       ...            False
# 4           0.875568  263042348       ...            False
#
#   face_beard_confidence face_mustache face_mustache_confidence face_smile  \
# 0             99.655762         False                98.480972       True
# 1             99.655762         False                98.480972       True
# 2             99.655762         False                98.480972       True
# 3             99.655762         False                98.480972       True
# 4             99.655762         False                98.480972       True
#
#    face_smile_confidence  eyeglasses  eyeglasses_confidence   face_emo  \
# 0              87.779747       False               99.99987      HAPPY
# 1              87.779747       False               99.99987        SAD
# 2              87.779747       False               99.99987  SURPRISED
# 3              87.779747       False               99.99987      HAPPY
# 4              87.779747       False               99.99987        SAD
#
#    emo_confidence
# 0        96.51368
# 1         2.52015
# 2        11.01824
# 3        96.51368
# 4         2.52015
#
# [5 rows x 40 columns]

# %%
print 'The number of unique users who took the Survey is: '+str(len(survey_df['insta_user_id'].unique()))
print 'The number of unique users in  the image data-set is: '+str(len(im_anp_obj_face_frame['user_id'].unique()))
# Out:
# The number of unique users who took the Survey is: 329
# The number of unique users in  the image data-set is: 144

# %% [markdown]
# It seems that there is a conflict between the <b>'user-id'</b> in the <b>im_anp_obj_face_frame</b> dataframe and the <b>'insta_user_id'</b> in the <b>survey_df</b> dateframe. This conflict exists because the two columns are from different format (one is a string and the other a float). In  order to be able to merge them we need to convert the string values to  float.

# %%
im_anp_obj_face_frame['user_id'] = im_anp_obj_face_frame['user_id'].apply(lambda x : float(x))

# %%
import datetime

#convert all the image_posted_time strings to datime object for tracking the year of creation 
im_anp_obj_face_frame['image_posted_time'] = im_anp_obj_face_frame['image_posted_time'].apply(lambda x : datetime.datetime.strptime(x, '%d-%m-%Y %H:%M:%S'))

# %%
#keeps only the last two year images of the users
years = ['2016','2017']
last_years = im_anp_obj_face_frame['image_posted_time'].apply(lambda x : True if str(x.year) in years else False)
last_years_images = im_anp_obj_face_frame[last_years.values]
print 'The last year dataframe has '+ str(len(last_years_images['user_id'].unique()))+' users.'
# Out:
# The last year dataframe has 127 users.

# %%
#merge the image dataframe with the survey dataframe 
image_survey = pd.merge(last_years_images,survey_df,left_on='user_id',right_on = 'insta_user_id')
print image_survey.shape
print 'The merging dataframe has '+ str(len(image_survey['user_id'].unique()))+' users.'
# Out:
# (1078350, 85)
# The merging dataframe has 127 users.

# %% [markdown]
# # Further Pre-Processing

# %% [markdown]
# Because there are some missing values (NaN)  in the of the explanatory variables of the merging dataframework we need to further pre process our data by excluding the rows that have NaN values.

# %%
image_survey = image_survey.dropna()
print image_survey.shape
print 'The merging dataframe has '+ str(len(image_survey['user_id'].unique()))+' users.'
# Out:
# (1075410, 85)
# The merging dataframe has 126 users.

# %% [markdown]
# # Correlation Coefficients

# %%
# Calculate the correlation coefficients. Notice how the main diagonal is 1.00

correlation_matrix = im_anp_obj_face_frame.corr()
correlation_matrix
# Out:
#                            image_height  image_width  data_memorability  \
# image_height                   1.000000     0.367477           0.092194
# image_width                    0.367477     1.000000          -0.048363
# data_memorability              0.092194    -0.048363           1.000000
# user_id                       -0.032317     0.024987          -0.028486
# user_followed_by              -0.044179     0.032737          -0.010293
# user_follows                  -0.110193    -0.051495          -0.046380
# user_posted_photos             0.056780     0.062664          -0.067173
# anp_sentiment                  0.015892    -0.008777           0.106849
# emotion_score                  0.006732    -0.003462           0.055681
# data_amz_label_confidence      0.014332     0.000225           0.032926
# face_id                       -0.034337     0.026916          -0.315009
# face_gender_confidence        -0.008701    -0.009760           0.014746
# face_age_range_high           -0.052446    -0.010250          -0.107471
# face_age_range_low            -0.053418    -0.008285          -0.115616
# face_sunglasses                0.000161     0.001980          -0.032094
# face_beard                    -0.010690     0.027605          -0.063643
# face_beard_confidence          0.010262    -0.015589           0.047527
# face_mustache                 -0.007228     0.031723          -0.037170
# face_mustache_confidence       0.008502    -0.013112           0.044731
# face_smile                     0.000130    -0.018547           0.052936
# face_smile_confidence          0.008904    -0.009949           0.044846
# eyeglasses                     0.004826     0.008953          -0.033755
# eyeglasses_confidence          0.016588     0.003785           0.083209
# emo_confidence                -0.000509    -0.004968          -0.003185
#
#                             user_id  user_followed_by  user_follows  \
# image_height              -0.032317         -0.044179     -0.110193
# image_width                0.024987          0.032737     -0.051495
# data_memorability         -0.028486         -0.010293     -0.046380
# user_id                    1.000000          0.010289      0.067582
# user_followed_by           0.010289          1.000000      0.300155
# user_follows               0.067582          0.300155      1.000000
# user_posted_photos        -0.166396          0.150294      0.040369
# anp_sentiment             -0.014089         -0.011532     -0.017019
# emotion_score             -0.012419          0.002684      0.003237
# data_amz_label_confidence -0.003699          0.006521     -0.003662
# face_id                    0.011870         -0.014647      0.022166
# face_gender_confidence    -0.022307          0.006756      0.018167
# face_age_range_high       -0.028596          0.084766      0.089671
# face_age_range_low        -0.026246          0.077775      0.086768
# face_sunglasses            0.021957         -0.011087      0.013937
# face_beard                 0.033926          0.043988      0.004460
# face_beard_confidence     -0.049911         -0.028013     -0.005718
# face_mustache              0.039764          0.046854     -0.005291
# face_mustache_confidence  -0.052432         -0.025272      0.001897
# face_smile                -0.041536         -0.082719      0.007140
# face_smile_confidence     -0.065157         -0.052183      0.011807
# eyeglasses                 0.014768         -0.024712      0.010431
# eyeglasses_confidence     -0.028688         -0.008538     -0.003827
# emo_confidence            -0.016735         -0.013778      0.005050
#
#                            user_posted_photos  anp_sentiment  emotion_score  \
# image_height                         0.056780       0.015892       0.006732
# image_width                          0.062664      -0.008777      -0.003462
# data_memorability                   -0.067173       0.106849       0.055681
# user_id                             -0.166396      -0.014089      -0.012419
# user_followed_by                     0.150294      -0.011532       0.002684
# user_follows                         0.040369      -0.017019       0.003237
# user_posted_photos                   1.000000      -0.054813      -0.050928
# anp_sentiment                       -0.054813       1.000000       0.339011
# emotion_score                       -0.050928       0.339011       1.000000
# data_amz_label_confidence           -0.002424       0.005725       0.008191
# face_id                              0.024249      -0.059100      -0.020458
# face_gender_confidence               0.009058      -0.005834       0.005323
# face_age_range_high                  0.097951      -0.073432      -0.036045
# face_age_range_low                   0.099524      -0.070340      -0.036649
# face_sunglasses                      0.018212      -0.029941      -0.007838
# face_beard                           0.061977      -0.031011      -0.029593
# face_beard_confidence               -0.010526       0.020933       0.021920
# face_mustache                        0.064271      -0.023893      -0.027413
# face_mustache_confidence            -0.019818       0.019850       0.023165
# face_smile                          -0.064448       0.042821       0.039717
# face_smile_confidence               -0.019717       0.030767       0.029398
# eyeglasses                           0.083662      -0.042127      -0.019903
# eyeglasses_confidence               -0.024243       0.017479       0.015404
# emo_confidence                      -0.005419       0.004419       0.006878
#
#                            data_amz_label_confidence       ...        \
# image_height                                0.014332       ...
# image_width                                 0.000225       ...
# data_memorability                           0.032926       ...
# user_id                                    -0.003699       ...
# user_followed_by                            0.006521       ...
# user_follows                               -0.003662       ...
# user_posted_photos                         -0.002424       ...
# anp_sentiment                               0.005725       ...
# emotion_score                               0.008191       ...
# data_amz_label_confidence                   1.000000       ...
# face_id                                    -0.025877       ...
# face_gender_confidence                      0.001213       ...
# face_age_range_high                        -0.011930       ...
# face_age_range_low                         -0.013103       ...
# face_sunglasses                            -0.002400       ...
# face_beard                                  0.000109       ...
# face_beard_confidence                      -0.003093       ...
# face_mustache                              -0.004050       ...
# face_mustache_confidence                    0.001187       ...
# face_smile                                  0.002615       ...
# face_smile_confidence                      -0.001492       ...
# eyeglasses                                 -0.004318       ...
# eyeglasses_confidence                       0.007987       ...
# emo_confidence                             -0.001657       ...
#
#                            face_sunglasses  face_beard  face_beard_confidence  \
# image_height                      0.000161   -0.010690               0.010262
# image_width                       0.001980    0.027605              -0.015589
# data_memorability                -0.032094   -0.063643               0.047527
# user_id                           0.021957    0.033926              -0.049911
# user_followed_by                 -0.011087    0.043988              -0.028013
# user_follows                      0.013937    0.004460              -0.005718
# user_posted_photos                0.018212    0.061977              -0.010526
# anp_sentiment                    -0.029941   -0.031011               0.020933
# emotion_score                    -0.007838   -0.029593               0.021920
# data_amz_label_confidence        -0.002400    0.000109              -0.003093
# face_id                           0.036708    0.013296              -0.003710
# face_gender_confidence           -0.024328    0.001702               0.007847
# face_age_range_high               0.048594    0.183553              -0.091187
# face_age_range_low                0.039953    0.196486              -0.091217
# face_sunglasses                   1.000000    0.051923              -0.063532
# face_beard                        0.051923    1.000000              -0.298913
# face_beard_confidence            -0.063532   -0.298913               1.000000
# face_mustache                     0.051011    0.680913              -0.193155
# face_mustache_confidence         -0.072344   -0.334525               0.429438
# face_smile                       -0.005186   -0.020284               0.043524
# face_smile_confidence            -0.013613   -0.061589               0.060583
# eyeglasses                        0.426787    0.110675              -0.072350
# eyeglasses_confidence            -0.012112   -0.082774               0.066496
# emo_confidence                    0.002374   -0.033928               0.020794
#
#                            face_mustache  face_mustache_confidence  \
# image_height                   -0.007228                  0.008502
# image_width                     0.031723                 -0.013112
# data_memorability              -0.037170                  0.044731
# user_id                         0.039764                 -0.052432
# user_followed_by                0.046854                 -0.025272
# user_follows                   -0.005291                  0.001897
# user_posted_photos              0.064271                 -0.019818
# anp_sentiment                  -0.023893                  0.019850
# emotion_score                  -0.027413                  0.023165
# data_amz_label_confidence      -0.004050                  0.001187
# face_id                         0.005873                 -0.005058
# face_gender_confidence          0.001170                  0.015422
# face_age_range_high             0.170000                 -0.093795
# face_age_range_low              0.182792                 -0.096365
# face_sunglasses                 0.051011                 -0.072344
# face_beard                      0.680913                 -0.334525
# face_beard_confidence          -0.193155                  0.429438
# face_mustache                   1.000000                 -0.324081
# face_mustache_confidence       -0.324081                  1.000000
# face_smile                     -0.017414                  0.042795
# face_smile_confidence          -0.057879                  0.056200
# eyeglasses                      0.089051                 -0.066166
# eyeglasses_confidence          -0.056019                  0.060187
# emo_confidence                 -0.029996                  0.020492
#
#                            face_smile  face_smile_confidence  eyeglasses  \
# image_height                 0.000130               0.008904    0.004826
# image_width                 -0.018547              -0.009949    0.008953
# data_memorability            0.052936               0.044846   -0.033755
# user_id                     -0.041536              -0.065157    0.014768
# user_followed_by            -0.082719              -0.052183   -0.024712
# user_follows                 0.007140               0.011807    0.010431
# user_posted_photos          -0.064448              -0.019717    0.083662
# anp_sentiment                0.042821               0.030767   -0.042127
# emotion_score                0.039717               0.029398   -0.019903
# data_amz_label_confidence    0.002615              -0.001492   -0.004318
# face_id                     -0.023133              -0.011505    0.009042
# face_gender_confidence       0.031535               0.020220   -0.017012
# face_age_range_high         -0.012787              -0.019397    0.108730
# face_age_range_low          -0.015908              -0.021028    0.104830
# face_sunglasses             -0.005186              -0.013613    0.426787
# face_beard                  -0.020284              -0.061589    0.110675
# face_beard_confidence        0.043524               0.060583   -0.072350
# face_mustache               -0.017414              -0.057879    0.089051
# face_mustache_confidence     0.042795               0.056200   -0.066166
# face_smile                   1.000000               0.194081   -0.005535
# face_smile_confidence        0.194081               1.000000   -0.036652
# eyeglasses                  -0.005535              -0.036652    1.000000
# eyeglasses_confidence        0.029517               0.035847   -0.166852
# emo_confidence               0.077528               0.060597   -0.009750
#
#                            eyeglasses_confidence  emo_confidence
# image_height                            0.016588       -0.000509
# image_width                             0.003785       -0.004968
# data_memorability                       0.083209       -0.003185
# user_id                                -0.028688       -0.016735
# user_followed_by                       -0.008538       -0.013778
# user_follows                           -0.003827        0.005050
# user_posted_photos                     -0.024243       -0.005419
# anp_sentiment                           0.017479        0.004419
# emotion_score                           0.015404        0.006878
# data_amz_label_confidence               0.007987       -0.001657
# face_id                                -0.027795        0.005240
# face_gender_confidence                  0.012206        0.004159
# face_age_range_high                    -0.019763       -0.004199
# face_age_range_low                     -0.025025       -0.006367
# face_sunglasses                        -0.012112        0.002374
# face_beard                             -0.082774       -0.033928
# face_beard_confidence                   0.066496        0.020794
# face_mustache                          -0.056019       -0.029996
# face_mustache_confidence                0.060187        0.020492
# face_smile                              0.029517        0.077528
# face_smile_confidence                   0.035847        0.060597
# eyeglasses                             -0.166852       -0.009750
# eyeglasses_confidence                   1.000000        0.010283
# emo_confidence                          0.010283        1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# ** To-Do 3: Plot the correlation matrix with color codes corresponding to the how much two attributes are correlated. **
#
# ** To-Do 4: Calculate the Spearman rank for the attributes. **

# %% [markdown]
# ### ASSIGNMENT
#
# In this notebook we learned how to train and test a regressor on numerical data. For this assignment you are required to do the following:
#
# 1. Split the data into training and testing splits
# 2. Train a regressor to predict the PERMA scores on the test set using different sets of attributes (not all of them at once)
# 3. Analyze which features (attributes) correlate well with each other and help in fitting the curve to the data better.
# 4. Elaborate on the results.

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # TO-DO:3

# %%
mask = np.zeros_like(correlation_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation_matrix, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Calculate the correlation coefficients. Notice how the main diagonal is 1.00

correlation_matrix_survey = image_survey.corr()
correlation_matrix_survey
# Out:
#                            image_height  image_width  data_memorability  \
# image_height                   1.000000     0.294873           0.187916
# image_width                    0.294873     1.000000          -0.039727
# data_memorability              0.187916    -0.039727           1.000000
# user_id                       -0.062445    -0.074977          -0.032019
# user_followed_by              -0.073135     0.014143          -0.056725
# user_follows                  -0.122878    -0.075136          -0.059096
# user_posted_photos             0.075085     0.062282          -0.069911
# anp_sentiment                  0.040190     0.008126           0.124548
# emotion_score                  0.014304     0.001224           0.051464
# data_amz_label_confidence      0.019891    -0.003286           0.030595
# face_id                       -0.070626     0.030565          -0.305913
# face_gender_confidence        -0.016264    -0.009508          -0.003759
# face_age_range_high           -0.091155    -0.026199          -0.117148
# face_age_range_low            -0.093462    -0.025051          -0.122463
# face_sunglasses               -0.006641     0.002040          -0.066239
# face_beard                    -0.033944     0.009121          -0.055644
# face_beard_confidence          0.026901    -0.004557           0.036891
# face_mustache                 -0.022764     0.019578          -0.019661
# face_mustache_confidence       0.027274     0.002146           0.021458
# face_smile                     0.004144     0.012174           0.051969
# face_smile_confidence          0.018239     0.002764           0.033447
# eyeglasses                     0.004272    -0.002102          -0.047820
# eyeglasses_confidence          0.030253     0.001486           0.083102
# emo_confidence                 0.001905     0.001021          -0.006886
# born                           0.093181     0.027470           0.131888
# A_2                            0.003901     0.083786          -0.015017
# N_1                            0.040964    -0.065685           0.035132
# P_1                           -0.020876     0.061532           0.047460
# E_1                           -0.026280     0.047589           0.002101
# A_1                           -0.077802    -0.009135          -0.003122
# H_1                           -0.038629     0.030592           0.032013
# M_1                           -0.031134     0.019744           0.003245
# R_1                            0.016392     0.037203          -0.016645
# M_2                           -0.066146     0.009628          -0.012927
# E_2                           -0.050180     0.018823           0.070247
# LON                           -0.012207    -0.050901          -0.012546
# H_2                           -0.030906     0.013392           0.035371
# P_2                           -0.007639     0.025873          -0.004721
# N_2                            0.089209    -0.037292           0.009603
# A_3                           -0.035044     0.015289          -0.012808
# N_3                           -0.004174    -0.060235          -0.017314
# E_3                            0.019206     0.009948          -0.038676
# H_3                           -0.046585     0.014246           0.020369
# R_2                            0.036318     0.072362           0.045881
# M_3                           -0.002135     0.013321           0.015054
# R_3                            0.067451     0.031979           0.032124
# P_3                            0.038627     0.071329           0.015626
# HAP                            0.005741     0.061249           0.015244
# insta_user_id                 -0.062445    -0.074977          -0.032019
# P                             -0.020876     0.061532           0.047460
# E                             -0.026280     0.047589           0.002101
# R                              0.016392     0.037203          -0.016645
# M                             -0.031134     0.019744           0.003245
# A                             -0.077802    -0.009135          -0.003122
# PERMA                         -0.020876     0.061532           0.047460
# N_EMO                          0.040964    -0.065685           0.035132
# P_EMO                         -0.020876     0.061532           0.047460
# imagecount                     0.081339     0.068182          -0.062470
#
#                             user_id  user_followed_by  user_follows  \
# image_height              -0.062445         -0.073135     -0.122878
# image_width               -0.074977          0.014143     -0.075136
# data_memorability         -0.032019         -0.056725     -0.059096
# user_id                    1.000000         -0.041248      0.012335
# user_followed_by          -0.041248          1.000000      0.274055
# user_follows               0.012335          0.274055      1.000000
# user_posted_photos        -0.236484          0.252826     -0.037476
# anp_sentiment             -0.028268         -0.027205     -0.025557
# emotion_score             -0.007096         -0.020084      0.003532
# data_amz_label_confidence -0.004773          0.016597      0.003087
# face_id                    0.015856          0.005028     -0.003860
# face_gender_confidence    -0.020552          0.012345      0.033102
# face_age_range_high       -0.010575          0.080212      0.119369
# face_age_range_low        -0.013904          0.075296      0.113015
# face_sunglasses            0.022680         -0.011941      0.037959
# face_beard                 0.003573          0.057434     -0.022864
# face_beard_confidence     -0.031444         -0.023539      0.018191
# face_mustache              0.008106          0.052322     -0.033541
# face_mustache_confidence  -0.037376         -0.035557      0.019693
# face_smile                -0.003946         -0.072669      0.016101
# face_smile_confidence     -0.045464         -0.046991      0.020374
# eyeglasses                 0.021422         -0.015104      0.016211
# eyeglasses_confidence     -0.022977         -0.025319      0.003418
# emo_confidence            -0.009712         -0.011823      0.011138
# born                      -0.011911          0.153478     -0.050751
# A_2                       -0.110193         -0.153371     -0.193664
# N_1                        0.061928         -0.113884      0.184097
# P_1                       -0.030357         -0.007065     -0.193456
# E_1                       -0.004451          0.130104      0.108896
# A_1                        0.150827         -0.007449     -0.006431
# H_1                       -0.208441         -0.098961      0.006382
# M_1                       -0.066350         -0.125890     -0.027808
# R_1                       -0.025785         -0.089699     -0.207905
# M_2                        0.036422         -0.073207     -0.138367
# E_2                        0.095213         -0.152174     -0.114839
# LON                        0.147900          0.136652      0.188237
# H_2                       -0.202784          0.019364     -0.036575
# P_2                       -0.014140         -0.070433     -0.116263
# N_2                        0.065203         -0.045782     -0.016309
# A_3                        0.028915         -0.035492     -0.013440
# N_3                        0.061594          0.103209      0.201700
# E_3                        0.116323         -0.195371      0.021793
# H_3                       -0.168750         -0.022745      0.048759
# R_2                       -0.032298         -0.146515     -0.224953
# M_3                        0.058906         -0.088150     -0.064568
# R_3                        0.028790         -0.294367     -0.071966
# P_3                        0.041825         -0.073295     -0.236697
# HAP                       -0.030783         -0.114499     -0.190106
# insta_user_id              1.000000         -0.041248      0.012335
# P                         -0.030357         -0.007065     -0.193456
# E                         -0.004451          0.130104      0.108896
# R                         -0.025785         -0.089699     -0.207905
# M                         -0.066350         -0.125890     -0.027808
# A                          0.150827         -0.007449     -0.006431
# PERMA                     -0.030357         -0.007065     -0.193456
# N_EMO                      0.061928         -0.113884      0.184097
# P_EMO                     -0.030357         -0.007065     -0.193456
# imagecount                -0.321194          0.187717     -0.025759
#
#                            user_posted_photos  anp_sentiment  emotion_score  \
# image_height                         0.075085       0.040190       0.014304
# image_width                          0.062282       0.008126       0.001224
# data_memorability                   -0.069911       0.124548       0.051464
# user_id                             -0.236484      -0.028268      -0.007096
# user_followed_by                     0.252826      -0.027205      -0.020084
# user_follows                        -0.037476      -0.025557       0.003532
# user_posted_photos                   1.000000      -0.081988      -0.092079
# anp_sentiment                       -0.081988       1.000000       0.347257
# emotion_score                       -0.092079       0.347257       1.000000
# data_amz_label_confidence           -0.002312       0.005765       0.005072
# face_id                              0.025148      -0.071678      -0.021838
# face_gender_confidence               0.020291      -0.018476       0.002741
# face_age_range_high                  0.140273      -0.114157      -0.053638
# face_age_range_low                   0.137696      -0.109115      -0.053988
# face_sunglasses                     -0.009377      -0.025357       0.000656
# face_beard                           0.113890      -0.041006      -0.023111
# face_beard_confidence               -0.011759       0.028983       0.013177
# face_mustache                        0.118247      -0.027168      -0.016377
# face_mustache_confidence            -0.028783       0.022838       0.009197
# face_smile                          -0.100798       0.035501       0.053349
# face_smile_confidence               -0.028712       0.028263       0.032485
# eyeglasses                           0.037054      -0.048700      -0.023024
# eyeglasses_confidence               -0.053449       0.031784       0.018855
# emo_confidence                      -0.017928       0.003925       0.008403
# born                                 0.087308       0.063069       0.036438
# A_2                                 -0.136550       0.006647       0.005198
# N_1                                 -0.216234       0.029227       0.025990
# P_1                                 -0.042644       0.039883       0.027318
# E_1                                 -0.142192       0.037007       0.038554
# A_1                                 -0.116503       0.013015       0.018929
# H_1                                 -0.277218       0.041231       0.017938
# M_1                                 -0.296667       0.057667       0.052627
# R_1                                 -0.371492       0.052390       0.045443
# M_2                                 -0.337591       0.057235       0.047079
# E_2                                 -0.492900       0.079629       0.063255
# LON                                  0.260098      -0.045658      -0.016036
# H_2                                 -0.212847       0.049442       0.025411
# P_2                                 -0.333250       0.060151       0.050243
# N_2                                  0.118743      -0.021267      -0.027096
# A_3                                 -0.257887       0.012910       0.030241
# N_3                                  0.165203      -0.031779      -0.008871
# E_3                                 -0.235520      -0.007264       0.017130
# H_3                                 -0.151232       0.038948       0.024937
# R_2                                 -0.263640       0.046711       0.028604
# M_3                                 -0.258173       0.046783       0.034908
# R_3                                 -0.126349       0.034826       0.010225
# P_3                                 -0.033229       0.017276       0.004357
# HAP                                 -0.267935       0.060875       0.040368
# insta_user_id                       -0.236484      -0.028268      -0.007096
# P                                   -0.042644       0.039883       0.027318
# E                                   -0.142192       0.037007       0.038554
# R                                   -0.371492       0.052390       0.045443
# M                                   -0.296667       0.057667       0.052627
# A                                   -0.116503       0.013015       0.018929
# PERMA                               -0.042644       0.039883       0.027318
# N_EMO                               -0.216234       0.029227       0.025990
# P_EMO                               -0.042644       0.039883       0.027318
# imagecount                           0.936588      -0.078231      -0.093154
#
#                            data_amz_label_confidence     ...      \
# image_height                                0.019891     ...
# image_width                                -0.003286     ...
# data_memorability                           0.030595     ...
# user_id                                    -0.004773     ...
# user_followed_by                            0.016597     ...
# user_follows                                0.003087     ...
# user_posted_photos                         -0.002312     ...
# anp_sentiment                               0.005765     ...
# emotion_score                               0.005072     ...
# data_amz_label_confidence                   1.000000     ...
# face_id                                    -0.022882     ...
# face_gender_confidence                     -0.006195     ...
# face_age_range_high                        -0.006671     ...
# face_age_range_low                         -0.008691     ...
# face_sunglasses                             0.003916     ...
# face_beard                                 -0.001718     ...
# face_beard_confidence                      -0.007862     ...
# face_mustache                              -0.009631     ...
# face_mustache_confidence                    0.008544     ...
# face_smile                                  0.005712     ...
# face_smile_confidence                      -0.002455     ...
# eyeglasses                                  0.001876     ...
# eyeglasses_confidence                       0.006527     ...
# emo_confidence                             -0.000338     ...
# born                                       -0.007406     ...
# A_2                                        -0.008570     ...
# N_1                                         0.012684     ...
# P_1                                        -0.005164     ...
# E_1                                         0.006609     ...
# A_1                                        -0.010440     ...
# H_1                                        -0.007071     ...
# M_1                                         0.005237     ...
# R_1                                         0.008441     ...
# M_2                                         0.009719     ...
# E_2                                         0.006575     ...
# LON                                        -0.004311     ...
# H_2                                        -0.007195     ...
# P_2                                        -0.002990     ...
# N_2                                        -0.002820     ...
# A_3                                         0.005235     ...
# N_3                                         0.002182     ...
# E_3                                         0.011867     ...
# H_3                                        -0.003164     ...
# R_2                                         0.009517     ...
# M_3                                         0.005915     ...
# R_3                                         0.003964     ...
# P_3                                        -0.004161     ...
# HAP                                         0.001244     ...
# insta_user_id                              -0.004773     ...
# P                                          -0.005164     ...
# E                                           0.006609     ...
# R                                           0.008441     ...
# M                                           0.005237     ...
# A                                          -0.010440     ...
# PERMA                                      -0.005164     ...
# N_EMO                                       0.012684     ...
# P_EMO                                      -0.005164     ...
# imagecount                                 -0.000630     ...
#
#                            insta_user_id         P         E         R  \
# image_height                   -0.062445 -0.020876 -0.026280  0.016392
# image_width                    -0.074977  0.061532  0.047589  0.037203
# data_memorability              -0.032019  0.047460  0.002101 -0.016645
# user_id                         1.000000 -0.030357 -0.004451 -0.025785
# user_followed_by               -0.041248 -0.007065  0.130104 -0.089699
# user_follows                    0.012335 -0.193456  0.108896 -0.207905
# user_posted_photos             -0.236484 -0.042644 -0.142192 -0.371492
# anp_sentiment                  -0.028268  0.039883  0.037007  0.052390
# emotion_score                  -0.007096  0.027318  0.038554  0.045443
# data_amz_label_confidence      -0.004773 -0.005164  0.006609  0.008441
# face_id                         0.015856 -0.007065  0.003700  0.023324
# face_gender_confidence         -0.020552  0.000889 -0.007640 -0.020197
# face_age_range_high            -0.010575 -0.038483 -0.064982 -0.129649
# face_age_range_low             -0.013904 -0.038403 -0.065436 -0.120528
# face_sunglasses                 0.022680  0.003965 -0.006465  0.002817
# face_beard                      0.003573  0.054350 -0.038233 -0.042747
# face_beard_confidence          -0.031444 -0.040315  0.034307  0.018990
# face_mustache                   0.008106  0.050672 -0.052183 -0.041697
# face_mustache_confidence       -0.037376 -0.026783  0.036402  0.022035
# face_smile                     -0.003946 -0.026465  0.037191  0.081261
# face_smile_confidence          -0.045464 -0.029502  0.019886  0.035365
# eyeglasses                      0.021422 -0.056194 -0.029449 -0.039474
# eyeglasses_confidence          -0.022977 -0.002773 -0.015918  0.039075
# emo_confidence                 -0.009712 -0.006665  0.008564  0.019349
# born                           -0.011911  0.098511 -0.041179 -0.033118
# A_2                            -0.110193  0.512739  0.396440  0.367418
# N_1                             0.061928 -0.372696 -0.075172 -0.086676
# P_1                            -0.030357  1.000000  0.376996  0.295314
# E_1                            -0.004451  0.376996  1.000000  0.237464
# A_1                             0.150827  0.594493  0.437427  0.327161
# H_1                            -0.208441  0.465348  0.273638  0.293462
# M_1                            -0.066350  0.536494  0.233476  0.531760
# R_1                            -0.025785  0.295314  0.237464  1.000000
# M_2                             0.036422  0.464887  0.408319  0.594382
# E_2                             0.095213  0.482328  0.440601  0.554887
# LON                             0.147900 -0.454826 -0.206619 -0.483275
# H_2                            -0.202784  0.466243  0.145320  0.287432
# P_2                            -0.014140  0.643067  0.309657  0.581516
# N_2                             0.065203 -0.256000 -0.080428 -0.117162
# A_3                             0.028915  0.443205  0.286371  0.255085
# N_3                             0.061594 -0.482716 -0.179519 -0.348046
# E_3                             0.116323  0.053089  0.145857  0.180402
# H_3                            -0.168750  0.471939  0.217105  0.374759
# R_2                            -0.032298  0.547146  0.210494  0.558206
# M_3                             0.058906  0.386646  0.378736  0.398048
# R_3                             0.028790  0.469151  0.263668  0.480719
# P_3                             0.041825  0.576205  0.284473  0.477373
# HAP                            -0.030783  0.599533  0.328775  0.576063
# insta_user_id                   1.000000 -0.030357 -0.004451 -0.025785
# P                              -0.030357  1.000000  0.376996  0.295314
# E                              -0.004451  0.376996  1.000000  0.237464
# R                              -0.025785  0.295314  0.237464  1.000000
# M                              -0.066350  0.536494  0.233476  0.531760
# A                               0.150827  0.594493  0.437427  0.327161
# PERMA                          -0.030357  1.000000  0.376996  0.295314
# N_EMO                           0.061928 -0.372696 -0.075172 -0.086676
# P_EMO                          -0.030357  1.000000  0.376996  0.295314
# imagecount                     -0.321194 -0.077698 -0.098106 -0.340922
#
#                                   M         A     PERMA     N_EMO     P_EMO  \
# image_height              -0.031134 -0.077802 -0.020876  0.040964 -0.020876
# image_width                0.019744 -0.009135  0.061532 -0.065685  0.061532
# data_memorability          0.003245 -0.003122  0.047460  0.035132  0.047460
# user_id                   -0.066350  0.150827 -0.030357  0.061928 -0.030357
# user_followed_by          -0.125890 -0.007449 -0.007065 -0.113884 -0.007065
# user_follows              -0.027808 -0.006431 -0.193456  0.184097 -0.193456
# user_posted_photos        -0.296667 -0.116503 -0.042644 -0.216234 -0.042644
# anp_sentiment              0.057667  0.013015  0.039883  0.029227  0.039883
# emotion_score              0.052627  0.018929  0.027318  0.025990  0.027318
# data_amz_label_confidence  0.005237 -0.010440 -0.005164  0.012684 -0.005164
# face_id                    0.025899  0.015603 -0.007065 -0.043436 -0.007065
# face_gender_confidence    -0.023934  0.010361  0.000889 -0.016837  0.000889
# face_age_range_high       -0.147387 -0.016002 -0.038483 -0.093518 -0.038483
# face_age_range_low        -0.132041 -0.018934 -0.038403 -0.093186 -0.038403
# face_sunglasses            0.010288  0.021833  0.003965  0.021097  0.003965
# face_beard                 0.002567  0.041670  0.054350 -0.101682  0.054350
# face_beard_confidence      0.015078 -0.025124 -0.040315  0.048242 -0.040315
# face_mustache              0.000607  0.036851  0.050672 -0.092263  0.050672
# face_mustache_confidence   0.025122 -0.005299 -0.026783  0.048705 -0.026783
# face_smile                 0.048975 -0.007541 -0.026465  0.047859 -0.026465
# face_smile_confidence      0.012681 -0.027214 -0.029502  0.026498 -0.029502
# eyeglasses                -0.075977 -0.066315 -0.056194  0.001112 -0.056194
# eyeglasses_confidence      0.026987 -0.015571 -0.002773  0.018479 -0.002773
# emo_confidence             0.014885 -0.002969 -0.006665  0.010926 -0.006665
# born                      -0.147024  0.037978  0.098511 -0.020231  0.098511
# A_2                        0.357740  0.490244  0.512739 -0.318537  0.512739
# N_1                       -0.097868 -0.360599 -0.372696  1.000000 -0.372696
# P_1                        0.536494  0.594493  1.000000 -0.372696  1.000000
# E_1                        0.233476  0.437427  0.376996 -0.075172  0.376996
# A_1                        0.541563  1.000000  0.594493 -0.360599  0.594493
# H_1                        0.474488  0.441952  0.465348 -0.106420  0.465348
# M_1                        1.000000  0.541563  0.536494 -0.097868  0.536494
# R_1                        0.531760  0.327161  0.295314 -0.086676  0.295314
# M_2                        0.666305  0.640057  0.464887 -0.213965  0.464887
# E_2                        0.561672  0.617571  0.482328 -0.082401  0.482328
# LON                       -0.502416 -0.469813 -0.454826  0.390218 -0.454826
# H_2                        0.464611  0.509625  0.466243 -0.261350  0.466243
# P_2                        0.639204  0.649465  0.643067 -0.206198  0.643067
# N_2                       -0.277310 -0.259497 -0.256000  0.595347 -0.256000
# A_3                        0.532479  0.550498  0.443205 -0.098782  0.443205
# N_3                       -0.443439 -0.478330 -0.482716  0.615755 -0.482716
# E_3                        0.320562  0.283360  0.053089  0.222900  0.053089
# H_3                        0.565840  0.550586  0.471939 -0.058246  0.471939
# R_2                        0.612165  0.466755  0.547146 -0.103923  0.547146
# M_3                        0.521864  0.611769  0.386646 -0.151150  0.386646
# R_3                        0.517965  0.534445  0.469151 -0.062598  0.469151
# P_3                        0.475491  0.596978  0.576205 -0.176233  0.576205
# HAP                        0.621795  0.597247  0.599533 -0.244630  0.599533
# insta_user_id             -0.066350  0.150827 -0.030357  0.061928 -0.030357
# P                          0.536494  0.594493  1.000000 -0.372696  1.000000
# E                          0.233476  0.437427  0.376996 -0.075172  0.376996
# R                          0.531760  0.327161  0.295314 -0.086676  0.295314
# M                          1.000000  0.541563  0.536494 -0.097868  0.536494
# A                          0.541563  1.000000  0.594493 -0.360599  0.594493
# PERMA                      0.536494  0.594493  1.000000 -0.372696  1.000000
# N_EMO                     -0.097868 -0.360599 -0.372696  1.000000 -0.372696
# P_EMO                      0.536494  0.594493  1.000000 -0.372696  1.000000
# imagecount                -0.276594 -0.187947 -0.077698 -0.132302 -0.077698
#
#                            imagecount
# image_height                 0.081339
# image_width                  0.068182
# data_memorability           -0.062470
# user_id                     -0.321194
# user_followed_by             0.187717
# user_follows                -0.025759
# user_posted_photos           0.936588
# anp_sentiment               -0.078231
# emotion_score               -0.093154
# data_amz_label_confidence   -0.000630
# face_id                      0.014669
# face_gender_confidence       0.013897
# face_age_range_high          0.120949
# face_age_range_low           0.117762
# face_sunglasses             -0.005366
# face_beard                   0.068634
# face_beard_confidence        0.001222
# face_mustache                0.076462
# face_mustache_confidence    -0.019195
# face_smile                  -0.092617
# face_smile_confidence       -0.014391
# eyeglasses                   0.043724
# eyeglasses_confidence       -0.048676
# emo_confidence              -0.014681
# born                         0.032145
# A_2                         -0.094523
# N_1                         -0.132302
# P_1                         -0.077698
# E_1                         -0.098106
# A_1                         -0.187947
# H_1                         -0.193864
# M_1                         -0.276594
# R_1                         -0.340922
# M_2                         -0.282923
# E_2                         -0.428481
# LON                          0.223035
# H_2                         -0.209385
# P_2                         -0.344812
# N_2                          0.141579
# A_3                         -0.228537
# N_3                          0.163660
# E_3                         -0.223272
# H_3                         -0.124803
# R_2                         -0.170795
# M_3                         -0.200943
# R_3                         -0.064329
# P_3                         -0.031785
# HAP                         -0.223627
# insta_user_id               -0.321194
# P                           -0.077698
# E                           -0.098106
# R                           -0.340922
# M                           -0.276594
# A                           -0.187947
# PERMA                       -0.077698
# N_EMO                       -0.132302
# P_EMO                       -0.077698
# imagecount                   1.000000
#
# [58 rows x 58 columns]

# %%
mask = np.zeros_like(correlation_matrix_survey, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation_matrix_survey, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # TO-DO:1

# %%
from sklearn.cross_validation import train_test_split

independent_variables = image_survey[list(correlation_matrix)]
dependent_variables = image_survey['PERMA']

x_train, x_test,  y_train, y_test = train_test_split(independent_variables,dependent_variables,test_size=0.2)
# Out:
# /home/aris/anaconda2/envs/tweets_USA/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
print x_train.shape
print x_test.shape

print y_train.shape
print y_test.shape
# Out:
# (860328, 24)
# (215082, 24)
# (860328,)
# (215082,)

# %% [markdown]
# # TO-DO:2

# %%
from sklearn.linear_model import LinearRegression
import time

start = time.time()
#This creates a LinearRegression object
lm = LinearRegression()
# Train the model using the training sets
lm.fit(x_train, y_train)

end = time.time()
print(end - start)
# Out:
# 1.64220404625

# %%
# Make predictions using the testing set
insta_y_pred = lm.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# The coefficients
print('Coefficients: \n', lm.coef_)
# The mean squared error
print("Mean squared error: %.2f"% mean_squared_error(y_test, insta_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, insta_y_pred))
# Out:
# ('Coefficients: \n', array([ -9.47635522e-04,   3.12280461e-03,   1.39505803e+00,
#         -8.02383944e-11,   1.58265977e-04,  -2.72304167e-04,
#         -1.43138290e-04,   8.11821244e-02,   3.32790611e-01,
#         -1.06893161e-03,   1.39430387e-04,   2.87460671e-03,
#          7.85444305e-03,  -1.33897494e-02,   1.95322085e-01,
#          1.62518433e-01,  -3.57065838e-03,   9.64736297e-02,
#          9.23702397e-04,  -9.35974036e-02,  -2.60336487e-03,
#         -2.47285215e-01,  -1.83106046e-03,   1.87888776e-05]))
# Mean squared error: 2.30
# Variance score: 0.06

# %%
#Construct a data frame that contains features and estimated coefficients.
pd.DataFrame(zip(X.columns, lm.coef_), columns = ['features', 'estimatedCoefficients'])

# %% [markdown]
# # Different linear library

# %%
import statsmodels.formula.api as smf

#REFERENCE---->http://www.ritchieng.com/machine-learning-evaluate-linear-regression-model/

columns =list(correlation_matrix)

# %%
value ='PERMA~'+ '+'.join(columns)

print value
# Out:
# PERMA~image_height+image_width+data_memorability+user_id+user_followed_by+user_follows+user_posted_photos+anp_sentiment+emotion_score+data_amz_label_confidence+face_id+face_gender_confidence+face_age_range_high+face_age_range_low+face_sunglasses+face_beard+face_beard_confidence+face_mustache+face_mustache_confidence+face_smile+face_smile_confidence+eyeglasses+eyeglasses_confidence+emo_confidence

# %%
### STATSMODELS ###

# create a fitted model with all three features
lm1 = smf.ols(formula=value, data=image_survey).fit()

# print the coefficients
lm1.params
# Out:
# Intercept                    4.674436e+00
# face_sunglasses[T.True]      1.973700e-01
# face_beard[T.True]           1.641334e-01
# face_mustache[T.True]        9.545568e-02
# face_smile[T.True]          -9.066100e-02
# eyeglasses[T.True]          -2.473662e-01
# image_height                -9.321302e-04
# image_width                  3.084530e-03
# data_memorability            1.397361e+00
# user_id                     -8.168182e-11
# user_followed_by             1.586150e-04
# user_follows                -2.727036e-04
# user_posted_photos          -1.443131e-04
# anp_sentiment                7.989108e-02
# emotion_score                3.185910e-01
# data_amz_label_confidence   -1.016158e-03
# face_id                      1.245629e-04
# face_gender_confidence       3.071389e-03
# face_age_range_high          7.651060e-03
# face_age_range_low          -1.303357e-02
# face_beard_confidence       -3.512453e-03
# face_mustache_confidence     9.454277e-04
# face_smile_confidence       -2.571028e-03
# eyeglasses_confidence       -1.780908e-03
# emo_confidence              -8.393793e-06
# dtype: float64

# %%
### STATSMODELS ###

# print a summary of the fitted model
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PERMA   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     3044.
# Date:                Sun, 15 Oct 2017   Prob (F-statistic):               0.00
# Time:                        19:53:30   Log-Likelihood:            -1.9750e+06
# No. Observations:             1075410   AIC:                         3.950e+06
# Df Residuals:                 1075385   BIC:                         3.950e+06
# Df Model:                          24
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     4.6744      0.053     88.147      0.000       4.570       4.778
# face_sunglasses[T.True]       0.1974      0.005     37.541      0.000       0.187       0.208
# face_beard[T.True]            0.1641      0.005     32.214      0.000       0.154       0.174
# face_mustache[T.True]         0.0955      0.005     17.849      0.000       0.085       0.106
# face_smile[T.True]           -0.0907      0.003    -26.923      0.000      -0.097      -0.084
# eyeglasses[T.True]           -0.2474      0.004    -65.381      0.000      -0.255      -0.240
# image_height                 -0.0009   1.42e-05    -65.582      0.000      -0.001      -0.001
# image_width                   0.0031   4.56e-05     67.693      0.000       0.003       0.003
# data_memorability             1.3974      0.030     47.253      0.000       1.339       1.455
# user_id                   -8.168e-11   1.88e-12    -43.363      0.000   -8.54e-11    -7.8e-11
# user_followed_by              0.0002   2.79e-06     56.829      0.000       0.000       0.000
# user_follows                 -0.0003    1.3e-06   -209.008      0.000      -0.000      -0.000
# user_posted_photos           -0.0001   1.99e-06    -72.388      0.000      -0.000      -0.000
# anp_sentiment                 0.0799      0.004     21.294      0.000       0.073       0.087
# emotion_score                 0.3186      0.022     14.504      0.000       0.276       0.362
# data_amz_label_confidence    -0.0010      0.000     -6.411      0.000      -0.001      -0.001
# face_id                       0.0001   4.67e-05      2.669      0.008    3.31e-05       0.000
# face_gender_confidence        0.0031      0.000     11.527      0.000       0.003       0.004
# face_age_range_high           0.0077      0.001     13.799      0.000       0.007       0.009
# face_age_range_low           -0.0130      0.001    -16.751      0.000      -0.015      -0.012
# face_beard_confidence        -0.0035      0.000    -24.711      0.000      -0.004      -0.003
# face_mustache_confidence      0.0009      0.000      6.166      0.000       0.001       0.001
# face_smile_confidence        -0.0026      0.000    -24.051      0.000      -0.003      -0.002
# eyeglasses_confidence        -0.0018      0.000    -12.038      0.000      -0.002      -0.001
# emo_confidence            -8.394e-06   4.16e-05     -0.202      0.840   -8.99e-05    7.31e-05
# ==============================================================================
# Omnibus:                    20082.554   Durbin-Watson:                   0.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28719.569
# Skew:                          -0.222   Prob(JB):                         0.00
# Kurtosis:                       3.666   Cond. No.                     3.75e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.75e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# calculate r-square 
lm1.rsquared
# Out:
# 0.063617563602254346

# %%
### STATSMODELS ###

# print the confidence intervals for the model coefficients
lm1.conf_int()
# Out:
#                                       0             1
# Intercept                  4.570499e+00  4.778373e+00
# face_sunglasses[T.True]    1.870657e-01  2.076743e-01
# face_beard[T.True]         1.541473e-01  1.741196e-01
# face_mustache[T.True]      8.497404e-02  1.059373e-01
# face_smile[T.True]        -9.726113e-02 -8.406088e-02
# eyeglasses[T.True]        -2.547815e-01 -2.399508e-01
# image_height              -9.599874e-04 -9.042729e-04
# image_width                2.995222e-03  3.173839e-03
# data_memorability          1.339401e+00  1.455320e+00
# user_id                   -8.537376e-11 -7.798987e-11
# user_followed_by           1.531445e-04  1.640855e-04
# user_follows              -2.752609e-04 -2.701463e-04
# user_posted_photos        -1.482205e-04 -1.404057e-04
# anp_sentiment              7.253759e-02  8.724457e-02
# emotion_score              2.755392e-01  3.616428e-01
# data_amz_label_confidence -1.326812e-03 -7.055050e-04
# face_id                    3.307878e-05  2.160471e-04
# face_gender_confidence     2.549158e-03  3.593621e-03
# face_age_range_high        6.564302e-03  8.737817e-03
# face_age_range_low        -1.455856e-02 -1.150857e-02
# face_beard_confidence     -3.791047e-03 -3.233859e-03
# face_mustache_confidence   6.448898e-04  1.245966e-03
# face_smile_confidence     -2.780543e-03 -2.361512e-03
# eyeglasses_confidence     -2.070857e-03 -1.490959e-03
# emo_confidence            -8.987907e-05  7.309149e-05

# %%
y_predict = lm1.predict(x_test)
y_predict.head()
# Out:
# 992473    6.439890
# 117917    6.650279
# 444182    6.795554
# 742310    4.985917
# 398057    6.513766
# dtype: float64

# %%
#sklearn predictions
insta_y_pred[:5]
# Out:
# array([ 6.44601402,  6.64993951,  6.79690331,  4.97945271,  6.5114858 ])

# %% [markdown]
# # Plot the residuals

# %%
residuals = y_test - insta_y_pred
residuals.head()
# Out:
# 992473   -0.446014
# 117917    0.350060
# 444182    0.203097
# 742310    1.020547
# 398057   -0.511486
# Name: PERMA, dtype: float64

# %%
#PERMA Scores are from  1-10

plt.scatter(y_test, insta_y_pred)
plt.xlabel("PERMA_Scores")
plt.ylabel("Predicted PERMA_Scores")
plt.title("")
plt.show()

# %% [markdown]
# It is clear that the regression model doesnt give accurate predictions for all the variables at once.
