# %% [markdown]
# The <b>mean squared error</b> has increased. So this shows that a single feature is not a good predictor of housing prices.
#
# ** To-Do 1: Make a train-test split and calculate the mean squared error for training data and test data.**
#
# ** To-Do 2: Plot the residuals for training and test datasets**

# %% [markdown]
# **In the next section, we are going to read in a feather file and assemble the dataset in one Pandas dataframe that
# we can work with.**
# Refer to the "explore_questionnaire.pdf" in the folder for detailed explanation of the dataset.
#
# <img src="./w56.png"/>
#
# To install and run feather use:
#
# **pip install feather-format** -- or else, (if you get import error) **pip install feather-format**

# %%
import feather
import numpy
import pandas as pd
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix

# Read feather frames to individual variables

anp_df = feather.read_dataframe('data_science_case/anp.feather')
face_df = feather.read_dataframe('data_science_case/face.feather')
image_df = feather.read_dataframe('data_science_case/image_data.feather')
metrics_df = feather.read_dataframe('data_science_case/image_metrics.feather')
object_labels_df = feather.read_dataframe('data_science_case/object_labels.feather')
survey_df = feather.read_dataframe('data_science_case/survey.feather')

# %%
anp_df.head()
# Out:
#                        image_id      anp_label  anp_sentiment  emotion_score  \
# 0  951727030670259635_143763900       hot_boys          0.017         0.1760
# 1  951727030670259635_143763900   young_couple          0.019         0.2113
# 2  951727030670259635_143763900  dirty_laundry         -0.263         0.0929
# 3  951727030670259635_143763900    global_mall         -0.031         0.1304
# 4  951728575726873168_289794729     high_boots          0.025         0.1394
#
#   emotion_label
# 0     amazement
# 1           joy
# 2           joy
# 3      interest
# 4     amazement

# %%
face_df.head()
# Out:
#                         image_id  face_id face_gender  face_gender_confidence  \
# 0  1003944279371027183_703978203      6.0      Female               98.741425
# 1  1003944279371027183_703978203      6.0      Female               98.741425
# 2  1003944279371027183_703978203      6.0      Female               98.741425
# 3  1003944279371027183_703978203     68.0        Male               99.927521
# 4  1003944279371027183_703978203     68.0        Male               99.927521
#
#    face_age_range_high  face_age_range_low  face_sunglasses  face_beard  \
# 0                 38.0                20.0            False       False
# 1                 38.0                20.0            False       False
# 2                 38.0                20.0            False       False
# 3                 77.0                57.0            False       False
# 4                 77.0                57.0            False       False
#
#    face_beard_confidence  face_mustache  face_mustache_confidence  face_smile  \
# 0              99.998474          False                 99.999794       False
# 1              99.998474          False                 99.999794       False
# 2              99.998474          False                 99.999794       False
# 3              99.981598          False                 99.993256       False
# 4              99.981598          False                 99.993256       False
#
#    face_smile_confidence  eyeglasses  eyeglasses_confidence   face_emo  \
# 0              99.916168        True              95.395546        SAD
# 1              99.916168        True              95.395546       CALM
# 2              99.916168        True              95.395546  SURPRISED
# 3              84.395294        True              99.420914      HAPPY
# 4              84.395294        True              99.420914        SAD
#
#    emo_confidence
# 0       12.660271
# 1        8.252973
# 2       24.634266
# 3       53.603287
# 4        5.509090

# %%
image_df.head()
# Out:
#                          image_id                                image_link  \
# 0  1316962883971761394_3468175004  https://www.instagram.com/p/BJGysPxgsTy/
# 1    552382455733335946_263042348   https://www.instagram.com/p/eqdOq2JLeK/
# 2    594552614686078174_263042348   https://www.instagram.com/p/hARnP2pLTe/
# 3    553884883234370621_263042348   https://www.instagram.com/p/evy13fpLQ9/
# 4    725551583154452417_263042348   https://www.instagram.com/p/oRrVIcJLfB/
#
#                                            image_url  image_height  \
# 0  https://scontent.cdninstagram.com/t51.2885-15/...         640.0
# 1  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 2  https://scontent.cdninstagram.com/t51.2885-15/...         640.0
# 3  https://scontent.cdninstagram.com/t51.2885-15/...         640.0
# 4  https://scontent.cdninstagram.com/t51.2885-15/...         640.0
#
#    image_width image_filter image_posted_time_unix    image_posted_time  \
# 0        640.0        Lo-fi             1471214231  14-08-2016 22:37:11
# 1        612.0       Normal             1380069141  25-09-2013 00:32:21
# 2        640.0       Vesper             1385096216  22-11-2013 04:56:56
# 3        640.0        Amaro             1380248245  27-09-2013 02:17:25
# 4        640.0        Amaro             1400712510  21-05-2014 22:48:30
#
#    data_memorability     user_id   user_full_name       user_name  \
# 0           0.800521  3468175004     Leah Jenkins     leah.chelle
# 1           0.875568   263042348  Taylor Degruise  taylordegruise
# 2           0.672679   263042348  Taylor Degruise  taylordegruise
# 3           0.843525   263042348  Taylor Degruise  taylordegruise
# 4           0.859796   263042348  Taylor Degruise  taylordegruise
#
#   user_website                                   user_profile_pic user_bio  \
# 0               https://scontent.cdninstagram.com/t51.2885-19/...
# 1               https://scontent.cdninstagram.com/t51.2885-19/...
# 2               https://scontent.cdninstagram.com/t51.2885-19/...
# 3               https://scontent.cdninstagram.com/t51.2885-19/...
# 4               https://scontent.cdninstagram.com/t51.2885-19/...
#
#    user_followed_by  user_follows  user_posted_photos
# 0               7.0           0.0                 1.0
# 1             316.0         347.0                73.0
# 2             316.0         347.0                73.0
# 3             316.0         347.0                73.0
# 4             316.0         347.0                73.0

# %%
metrics_df.head()
# Out:
#                          image_id  comment_count comment_count_time_created  \
# 0  1337283311810249709_3041716852            0.0        19-06-2017 19:33:26
# 1  1337283311810249709_3041716852            0.0        19-06-2017 19:23:26
# 2  1337834353379743556_3041716852            0.0        19-06-2017 19:33:26
# 3  1337834353379743556_3041716852            0.0        19-06-2017 19:23:26
# 4  1516356155708878303_3041716852            5.0        19-06-2017 19:23:07
#
#    like_count like_count_time_created
# 0        15.0     19-06-2017 19:23:26
# 1        15.0     19-06-2017 19:23:26
# 2        23.0     19-06-2017 19:23:26
# 3        23.0     19-06-2017 19:23:26
# 4        19.0     19-06-2017 19:23:07

# %%
object_labels_df.head()
# Out:
#                         image_id data_amz_label  data_amz_label_confidence
# 0   863479386465416946_545497348         Animal                  90.163101
# 1   916939688871507178_545497348         Animal                  83.518669
# 2   551681403589539797_545497348         Animal                  74.837212
# 3  1189285646274180856_545497348         Animal                  76.920967
# 4   962361211517974133_545497348         Animal                  71.223869

# %%
survey_df.head()
# Out:
#                                  id  gender  born             education  \
# 0  920bf027f7d13dbdc7b66b3d3324903c    Male  1975      College graduate
# 1  b433b2bfe49e28d0b7c45925b53084e0    Male  1978      College graduate
# 2  4becd8768d42ffa6ef0a17d827f230a2    Male  1980  High school graduate
# 3  01d90eeb34866d03c52925738da7865f    Male  1959      College graduate
# 4  f4f54676f75f47c17dc434cf68845328  Female  1990  High school graduate
#
#              employed              income  A_2  N_1  P_1  E_1  \
# 0  Employed for wages  $30,000 to $39,999    4    5    5    3
# 1  Employed for wages  $20,000 to $29,999    8    0    9    7
# 2       Self-employed  $40,000 to $49,999    7    7    6    9
# 3  Employed for wages  $10,000 to $19,999    6    4    1    5
# 4  Employed for wages  $80,000 to $89,999    7    3    8    7
#
#         ...         P    E    R    M    A  PERMA  N_EMO  P_EMO  imagecount  \
# 0       ...         5  3.0  6.0  6.0  4.0      5    5.0      5       465.0
# 1       ...         9  7.0  9.0  8.0  7.0      9    0.0      9         6.0
# 2       ...         6  9.0  6.0  6.0  8.0      6    7.0      6         NaN
# 3       ...         1  5.0  3.0  3.0  3.0      1    4.0      1         NaN
# 4       ...         8  7.0  8.0  8.0  7.0      8    3.0      8       767.0
#
#    private_account
# 0           public
# 1           public
# 2          private
# 3          private
# 4           public
#
# [5 rows x 45 columns]

# %%
list(survey_df)
# Out:
# [u'id',
#  u'gender',
#  u'born',
#  u'education',
#  u'employed',
#  u'income',
#  u'A_2',
#  u'N_1',
#  u'P_1',
#  u'E_1',
#  u'A_1',
#  u'H_1',
#  u'M_1',
#  u'R_1',
#  u'M_2',
#  u'E_2',
#  u'LON',
#  u'H_2',
#  u'P_2',
#  u'N_2',
#  u'A_3',
#  u'N_3',
#  u'E_3',
#  u'H_3',
#  u'R_2',
#  u'M_3',
#  u'R_3',
#  u'P_3',
#  u'HAP',
#  u'participate',
#  u'insta_user_id',
#  u'completed',
#  u'start_q',
#  u'end_q',
#  u'network_id',
#  u'P',
#  u'E',
#  u'R',
#  u'M',
#  u'A',
#  u'PERMA',
#  u'N_EMO',
#  u'P_EMO',
#  u'imagecount',
#  u'private_account']

# %%
print survey_df['start_q'].max()
print survey_df['start_q'].min()
print survey_df['end_q'].max()
print survey_df['end_q'].min()
# Out:
# 2017-03-23 15:11:19
# 2016-12-05 14:01:21
# 2017-03-23 15:16:17
# 2016-12-05 14:02:52

# %% [markdown]
# # Merging of the Image elements

# %%
# Merge them based on the image_id so that we have a large data frame containing all the elements

image_anp_frame = pd.merge(image_df, anp_df, how='inner', on='image_id')
im_anp_obj_frame = pd.merge(image_anp_frame, object_labels_df, how='inner', on='image_id')
im_anp_obj_face_frame = pd.merge(im_anp_obj_frame, face_df, how='inner', on='image_id')

# %%
im_anp_obj_face_frame.shape
# Out:
# (3887625, 40)

# %%
im_anp_obj_face_frame.head()
# Out:
#                        image_id                               image_link  \
# 0  552382455733335946_263042348  https://www.instagram.com/p/eqdOq2JLeK/
# 1  552382455733335946_263042348  https://www.instagram.com/p/eqdOq2JLeK/
# 2  552382455733335946_263042348  https://www.instagram.com/p/eqdOq2JLeK/
# 3  552382455733335946_263042348  https://www.instagram.com/p/eqdOq2JLeK/
# 4  552382455733335946_263042348  https://www.instagram.com/p/eqdOq2JLeK/
#
#                                            image_url  image_height  \
# 0  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 1  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 2  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 3  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
# 4  https://scontent.cdninstagram.com/t51.2885-15/...         612.0
#
#    image_width image_filter image_posted_time_unix   image_posted_time  \
# 0        612.0       Normal             1380069141 2013-09-25 00:32:21
# 1        612.0       Normal             1380069141 2013-09-25 00:32:21
# 2        612.0       Normal             1380069141 2013-09-25 00:32:21
# 3        612.0       Normal             1380069141 2013-09-25 00:32:21
# 4        612.0       Normal             1380069141 2013-09-25 00:32:21
#
#    data_memorability      user_id       ...       face_beard  \
# 0           0.875568  263042348.0       ...            False
# 1           0.875568  263042348.0       ...            False
# 2           0.875568  263042348.0       ...            False
# 3           0.875568  263042348.0       ...            False
# 4           0.875568  263042348.0       ...            False
#
#   face_beard_confidence face_mustache face_mustache_confidence face_smile  \
# 0             99.655762         False                98.480972       True
# 1             99.655762         False                98.480972       True
# 2             99.655762         False                98.480972       True
# 3             99.655762         False                98.480972       True
# 4             99.655762         False                98.480972       True
#
#    face_smile_confidence  eyeglasses  eyeglasses_confidence   face_emo  \
# 0              87.779747       False               99.99987      HAPPY
# 1              87.779747       False               99.99987        SAD
# 2              87.779747       False               99.99987  SURPRISED
# 3              87.779747       False               99.99987      HAPPY
# 4              87.779747       False               99.99987        SAD
#
#    emo_confidence
# 0        96.51368
# 1         2.52015
# 2        11.01824
# 3        96.51368
# 4         2.52015
#
# [5 rows x 40 columns]

# %%
print 'The number of unique users who took the Survey is: '+str(len(survey_df['insta_user_id'].unique()))
print 'The number of unique users in  the image data-set is: '+str(len(im_anp_obj_face_frame['user_id'].unique()))
# Out:
# The number of unique users who took the Survey is: 329
# The number of unique users in  the image data-set is: 144

# %% [markdown]
# It seems that there is a conflict between the <b>'user-id'</b> in the <b>im_anp_obj_face_frame</b> dataframe and the <b>'insta_user_id'</b> in the <b>survey_df</b> dateframe. This conflict exists because the two columns are from different format (one is a string and the other a float). In  order to be able to merge them we need to convert the string values to  float.

# %%
im_anp_obj_face_frame['user_id'] = im_anp_obj_face_frame['user_id'].apply(lambda x : float(x))

# %%
import datetime

#convert all the image_posted_time strings to datime object for tracking the year of creation 
im_anp_obj_face_frame['image_posted_time'] = im_anp_obj_face_frame['image_posted_time'].apply(lambda x : datetime.datetime.strptime(x, '%d-%m-%Y %H:%M:%S'))

# %%
#keeps only the last two year images of the users
years = ['2016','2017']
last_years = im_anp_obj_face_frame['image_posted_time'].apply(lambda x : True if str(x.year) in years else False)
last_years_images = im_anp_obj_face_frame[last_years.values]
print 'The last year dataframe has '+ str(len(last_years_images['user_id'].unique()))+' users.'
# Out:
# The last year dataframe has 127 users.

# %%
#merge the image dataframe with the survey dataframe 
image_survey = pd.merge(last_years_images,survey_df,left_on='user_id',right_on = 'insta_user_id')
print image_survey.shape
print 'The merging dataframe has '+ str(len(image_survey['user_id'].unique()))+' users.'
# Out:
# (1078350, 85)

# %% [markdown]
# # Further Pre-Processing

# %% [markdown]
# Because there are some missing values (NaN)  in the of the explanatory variables of the merging dataframework we need to further pre process our data by excluding the rows that have NaN values.

# %%
image_survey = image_survey.dropna()
print image_survey.shape
print 'The merging dataframe has '+ str(len(image_survey['user_id'].unique()))+' users.'

# %% [markdown]
# # Correlation Coefficients

# %%
# Calculate the correlation coefficients. Notice how the main diagonal is 1.00

correlation_matrix = im_anp_obj_face_frame.corr()
correlation_matrix
# Out:
#                            image_height  image_width  data_memorability  \
# image_height                   1.000000     0.367477           0.092194
# image_width                    0.367477     1.000000          -0.048363
# data_memorability              0.092194    -0.048363           1.000000
# user_id                       -0.032317     0.024987          -0.028486
# user_followed_by              -0.044179     0.032737          -0.010293
# user_follows                  -0.110193    -0.051495          -0.046380
# user_posted_photos             0.056780     0.062664          -0.067173
# anp_sentiment                  0.015892    -0.008777           0.106849
# emotion_score                  0.006732    -0.003462           0.055681
# data_amz_label_confidence      0.014332     0.000225           0.032926
# face_id                       -0.034337     0.026916          -0.315009
# face_gender_confidence        -0.008701    -0.009760           0.014746
# face_age_range_high           -0.052446    -0.010250          -0.107471
# face_age_range_low            -0.053418    -0.008285          -0.115616
# face_sunglasses                0.000161     0.001980          -0.032094
# face_beard                    -0.010690     0.027605          -0.063643
# face_beard_confidence          0.010262    -0.015589           0.047527
# face_mustache                 -0.007228     0.031723          -0.037170
# face_mustache_confidence       0.008502    -0.013112           0.044731
# face_smile                     0.000130    -0.018547           0.052936
# face_smile_confidence          0.008904    -0.009949           0.044846
# eyeglasses                     0.004826     0.008953          -0.033755
# eyeglasses_confidence          0.016588     0.003785           0.083209
# emo_confidence                -0.000509    -0.004968          -0.003185
#
#                             user_id  user_followed_by  user_follows  \
# image_height              -0.032317         -0.044179     -0.110193
# image_width                0.024987          0.032737     -0.051495
# data_memorability         -0.028486         -0.010293     -0.046380
# user_id                    1.000000          0.010289      0.067582
# user_followed_by           0.010289          1.000000      0.300155
# user_follows               0.067582          0.300155      1.000000
# user_posted_photos        -0.166396          0.150294      0.040369
# anp_sentiment             -0.014089         -0.011532     -0.017019
# emotion_score             -0.012419          0.002684      0.003237
# data_amz_label_confidence -0.003699          0.006521     -0.003662
# face_id                    0.011870         -0.014647      0.022166
# face_gender_confidence    -0.022307          0.006756      0.018167
# face_age_range_high       -0.028596          0.084766      0.089671
# face_age_range_low        -0.026246          0.077775      0.086768
# face_sunglasses            0.021957         -0.011087      0.013937
# face_beard                 0.033926          0.043988      0.004460
# face_beard_confidence     -0.049911         -0.028013     -0.005718
# face_mustache              0.039764          0.046854     -0.005291
# face_mustache_confidence  -0.052432         -0.025272      0.001897
# face_smile                -0.041536         -0.082719      0.007140
# face_smile_confidence     -0.065157         -0.052183      0.011807
# eyeglasses                 0.014768         -0.024712      0.010431
# eyeglasses_confidence     -0.028688         -0.008538     -0.003827
# emo_confidence            -0.016735         -0.013778      0.005050
#
#                            user_posted_photos  anp_sentiment  emotion_score  \
# image_height                         0.056780       0.015892       0.006732
# image_width                          0.062664      -0.008777      -0.003462
# data_memorability                   -0.067173       0.106849       0.055681
# user_id                             -0.166396      -0.014089      -0.012419
# user_followed_by                     0.150294      -0.011532       0.002684
# user_follows                         0.040369      -0.017019       0.003237
# user_posted_photos                   1.000000      -0.054813      -0.050928
# anp_sentiment                       -0.054813       1.000000       0.339011
# emotion_score                       -0.050928       0.339011       1.000000
# data_amz_label_confidence           -0.002424       0.005725       0.008191
# face_id                              0.024249      -0.059100      -0.020458
# face_gender_confidence               0.009058      -0.005834       0.005323
# face_age_range_high                  0.097951      -0.073432      -0.036045
# face_age_range_low                   0.099524      -0.070340      -0.036649
# face_sunglasses                      0.018212      -0.029941      -0.007838
# face_beard                           0.061977      -0.031011      -0.029593
# face_beard_confidence               -0.010526       0.020933       0.021920
# face_mustache                        0.064271      -0.023893      -0.027413
# face_mustache_confidence            -0.019818       0.019850       0.023165
# face_smile                          -0.064448       0.042821       0.039717
# face_smile_confidence               -0.019717       0.030767       0.029398
# eyeglasses                           0.083662      -0.042127      -0.019903
# eyeglasses_confidence               -0.024243       0.017479       0.015404
# emo_confidence                      -0.005419       0.004419       0.006878
#
#                            data_amz_label_confidence       ...        \
# image_height                                0.014332       ...
# image_width                                 0.000225       ...
# data_memorability                           0.032926       ...
# user_id                                    -0.003699       ...
# user_followed_by                            0.006521       ...
# user_follows                               -0.003662       ...
# user_posted_photos                         -0.002424       ...
# anp_sentiment                               0.005725       ...
# emotion_score                               0.008191       ...
# data_amz_label_confidence                   1.000000       ...
# face_id                                    -0.025877       ...
# face_gender_confidence                      0.001213       ...
# face_age_range_high                        -0.011930       ...
# face_age_range_low                         -0.013103       ...
# face_sunglasses                            -0.002400       ...
# face_beard                                  0.000109       ...
# face_beard_confidence                      -0.003093       ...
# face_mustache                              -0.004050       ...
# face_mustache_confidence                    0.001187       ...
# face_smile                                  0.002615       ...
# face_smile_confidence                      -0.001492       ...
# eyeglasses                                 -0.004318       ...
# eyeglasses_confidence                       0.007987       ...
# emo_confidence                             -0.001657       ...
#
#                            face_sunglasses  face_beard  face_beard_confidence  \
# image_height                      0.000161   -0.010690               0.010262
# image_width                       0.001980    0.027605              -0.015589
# data_memorability                -0.032094   -0.063643               0.047527
# user_id                           0.021957    0.033926              -0.049911
# user_followed_by                 -0.011087    0.043988              -0.028013
# user_follows                      0.013937    0.004460              -0.005718
# user_posted_photos                0.018212    0.061977              -0.010526
# anp_sentiment                    -0.029941   -0.031011               0.020933
# emotion_score                    -0.007838   -0.029593               0.021920
# data_amz_label_confidence        -0.002400    0.000109              -0.003093
# face_id                           0.036708    0.013296              -0.003710
# face_gender_confidence           -0.024328    0.001702               0.007847
# face_age_range_high               0.048594    0.183553              -0.091187
# face_age_range_low                0.039953    0.196486              -0.091217
# face_sunglasses                   1.000000    0.051923              -0.063532
# face_beard                        0.051923    1.000000              -0.298913
# face_beard_confidence            -0.063532   -0.298913               1.000000
# face_mustache                     0.051011    0.680913              -0.193155
# face_mustache_confidence         -0.072344   -0.334525               0.429438
# face_smile                       -0.005186   -0.020284               0.043524
# face_smile_confidence            -0.013613   -0.061589               0.060583
# eyeglasses                        0.426787    0.110675              -0.072350
# eyeglasses_confidence            -0.012112   -0.082774               0.066496
# emo_confidence                    0.002374   -0.033928               0.020794
#
#                            face_mustache  face_mustache_confidence  \
# image_height                   -0.007228                  0.008502
# image_width                     0.031723                 -0.013112
# data_memorability              -0.037170                  0.044731
# user_id                         0.039764                 -0.052432
# user_followed_by                0.046854                 -0.025272
# user_follows                   -0.005291                  0.001897
# user_posted_photos              0.064271                 -0.019818
# anp_sentiment                  -0.023893                  0.019850
# emotion_score                  -0.027413                  0.023165
# data_amz_label_confidence      -0.004050                  0.001187
# face_id                         0.005873                 -0.005058
# face_gender_confidence          0.001170                  0.015422
# face_age_range_high             0.170000                 -0.093795
# face_age_range_low              0.182792                 -0.096365
# face_sunglasses                 0.051011                 -0.072344
# face_beard                      0.680913                 -0.334525
# face_beard_confidence          -0.193155                  0.429438
# face_mustache                   1.000000                 -0.324081
# face_mustache_confidence       -0.324081                  1.000000
# face_smile                     -0.017414                  0.042795
# face_smile_confidence          -0.057879                  0.056200
# eyeglasses                      0.089051                 -0.066166
# eyeglasses_confidence          -0.056019                  0.060187
# emo_confidence                 -0.029996                  0.020492
#
#                            face_smile  face_smile_confidence  eyeglasses  \
# image_height                 0.000130               0.008904    0.004826
# image_width                 -0.018547              -0.009949    0.008953
# data_memorability            0.052936               0.044846   -0.033755
# user_id                     -0.041536              -0.065157    0.014768
# user_followed_by            -0.082719              -0.052183   -0.024712
# user_follows                 0.007140               0.011807    0.010431
# user_posted_photos          -0.064448              -0.019717    0.083662
# anp_sentiment                0.042821               0.030767   -0.042127
# emotion_score                0.039717               0.029398   -0.019903
# data_amz_label_confidence    0.002615              -0.001492   -0.004318
# face_id                     -0.023133              -0.011505    0.009042
# face_gender_confidence       0.031535               0.020220   -0.017012
# face_age_range_high         -0.012787              -0.019397    0.108730
# face_age_range_low          -0.015908              -0.021028    0.104830
# face_sunglasses             -0.005186              -0.013613    0.426787
# face_beard                  -0.020284              -0.061589    0.110675
# face_beard_confidence        0.043524               0.060583   -0.072350
# face_mustache               -0.017414              -0.057879    0.089051
# face_mustache_confidence     0.042795               0.056200   -0.066166
# face_smile                   1.000000               0.194081   -0.005535
# face_smile_confidence        0.194081               1.000000   -0.036652
# eyeglasses                  -0.005535              -0.036652    1.000000
# eyeglasses_confidence        0.029517               0.035847   -0.166852
# emo_confidence               0.077528               0.060597   -0.009750
#
#                            eyeglasses_confidence  emo_confidence
# image_height                            0.016588       -0.000509
# image_width                             0.003785       -0.004968
# data_memorability                       0.083209       -0.003185
# user_id                                -0.028688       -0.016735
# user_followed_by                       -0.008538       -0.013778
# user_follows                           -0.003827        0.005050
# user_posted_photos                     -0.024243       -0.005419
# anp_sentiment                           0.017479        0.004419
# emotion_score                           0.015404        0.006878
# data_amz_label_confidence               0.007987       -0.001657
# face_id                                -0.027795        0.005240
# face_gender_confidence                  0.012206        0.004159
# face_age_range_high                    -0.019763       -0.004199
# face_age_range_low                     -0.025025       -0.006367
# face_sunglasses                        -0.012112        0.002374
# face_beard                             -0.082774       -0.033928
# face_beard_confidence                   0.066496        0.020794
# face_mustache                          -0.056019       -0.029996
# face_mustache_confidence                0.060187        0.020492
# face_smile                              0.029517        0.077528
# face_smile_confidence                   0.035847        0.060597
# eyeglasses                             -0.166852       -0.009750
# eyeglasses_confidence                   1.000000        0.010283
# emo_confidence                          0.010283        1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# ** To-Do 3: Plot the correlation matrix with color codes corresponding to the how much two attributes are correlated. **
#
# ** To-Do 4: Calculate the Spearman rank for the attributes. **

# %% [markdown]
# ### ASSIGNMENT
#
# In this notebook we learned how to train and test a regressor on numerical data. For this assignment you are required to do the following:
#
# 1. Split the data into training and testing splits
# 2. Train a regressor to predict the PERMA scores on the test set using different sets of attributes (not all of them at once)
# 3. Analyze which features (attributes) correlate well with each other and help in fitting the curve to the data better.
# 4. Elaborate on the results.

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # TO-DO:3

# %%
mask = np.zeros_like(correlation_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation_matrix, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # TO-DO:1

# %%
from sklearn.cross_validation import train_test_split

independent_variables = image_survey[list(correlation_matrix)]
dependent_variables = image_survey['PERMA']

x_train, x_test,  y_train, y_test = train_test_split(independent_variables,dependent_variables,test_size=0.2)

# %%
print x_train.shape
print x_test.shape

print y_train.shape
print y_test.shape
# Out:
# (862680, 24)
# (215670, 24)
# (862680,)
# (215670,)

# %%
from sklearn.linear_model import LinearRegression
import time

start = time.time()
#This creates a LinearRegression object
lm = LinearRegression()
# Train the model using the training sets
lm.fit(x_train, y_train)

end = time.time()
print(end - start)
