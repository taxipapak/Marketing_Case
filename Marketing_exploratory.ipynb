# %% [markdown]
# # Fundamentals of Data Science - Week 5 and Week 6
#
# ###  <span style='color: green'>Scroll down to the bottom of the notebook to see your assignment</span>
# <p></p>
# <span style='color: red'>Deadline: **25.10.2017 (Wednesday) at 23:55 CEST**</span>

# %% [markdown]
# In this notebook, the first section is going to cover the following practical aspects of data science:
# + Creating a Linear Regression model
# + Predicting the model on unseen data and calculating error on the predicted score vs orginal score
# + Create a simple linear regression (with a single variable and a target) on the Diabetes dataset
# + Fit a linear model on the data and plot it
# + Create multivariate linear regression to predict house prices in Boston
# + Plot correlation between variables, predicted price vs original price and calculate mean square errors

# %%
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
import seaborn as sns

# %% [markdown]
# The <b>mean squared error</b> has increased. So this shows that a single feature is not a good predictor of housing prices.
#
# ** To-Do 1: Make a train-test split and calculate the mean squared error for training data and test data.**
#
# ** To-Do 2: Plot the residuals for training and test datasets**

# %% [markdown]
# **In the next section, we are going to read in a feather file and assemble the dataset in one Pandas dataframe that we can work with.**
# Refer to the "explore_questionnaire.pdf" in the folder for detailed explanation of the dataset.
#
# <img src="./w56.png"/>
#
# To install and run feather use:
#
# **pip install feather-format** -- or else, (if you get import error) **pip install feather-format**

# %%
import feather
import numpy
import pandas as pd
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix

# Read feather frames to individual variables

anp_df = feather.read_dataframe('data_science_case/anp.feather')
face_df = feather.read_dataframe('data_science_case/face.feather')
image_df = feather.read_dataframe('data_science_case/image_data.feather')
metrics_df = feather.read_dataframe('data_science_case/image_metrics.feather')
object_labels_df = feather.read_dataframe('data_science_case/object_labels.feather')
survey_df = feather.read_dataframe('data_science_case/survey.feather')

# %% [markdown]
# ## Investigate ANP matrix:

# %%
anp_df.head()
# Out:
#                        image_id      anp_label  anp_sentiment  emotion_score  \
# 0  951727030670259635_143763900       hot_boys          0.017         0.1760
# 1  951727030670259635_143763900   young_couple          0.019         0.2113
# 2  951727030670259635_143763900  dirty_laundry         -0.263         0.0929
# 3  951727030670259635_143763900    global_mall         -0.031         0.1304
# 4  951728575726873168_289794729     high_boots          0.025         0.1394
#
#   emotion_label
# 0     amazement
# 1           joy
# 2           joy
# 3      interest
# 4     amazement

# %% [markdown]
# For each image, we are given a certain 'topic/label' classification

# %%
print anp_df.emotion_label.unique()
# Out:
# [u'amazement' u'joy' u'interest' u'sadness' u'anger' u'terror' u'serenity'
#  u'fear' u'trust' u'surprise' u'grief' u'rage' u'boredom' u'ecstasy'
#  u'annoyance' u'disgust' u'pensiveness' u'acceptance' u'distraction'
#  u'anticipation' u'vigilance' u'loathing' u'apprehension' u'admiration']

# %% [markdown]
# Basically, each image is assigned a label (ex. hot_boys, young_couple, dirty_laundry) and each label has a certain emotion label (ex. Joy, vigilance, interest etc) along with a score (emotion_score) which corresponds to what is the percentage of "joy" in the "dirty laundry" label

# %%
anp_df.describe()
# Out:
#        anp_sentiment  emotion_score
# count  325941.000000  325941.000000
# mean        0.064778       0.162398
# std         0.396601       0.070143
# min        -2.363000       0.041700
# 25%        -0.068000       0.114800
# 50%         0.010000       0.146200
# 75%         0.158000       0.194900
# max         2.160000       0.734700

# %%
for anp_label in anp_df['anp_label'].unique()[:10]:
    print 'Images labeled with the ',anp_label, 'tag: show',anp_df[(anp_df.anp_label==anp_label)].emotion_score.unique()[0],anp_df[(anp_df.anp_label==anp_label)].emotion_label.unique()[0]
# Out:
# Images labeled with the  hot_boys tag: show 0.176 amazement
# Images labeled with the  young_couple tag: show 0.2113 joy
# Images labeled with the  dirty_laundry tag: show 0.0929 joy
# Images labeled with the  global_mall tag: show 0.1304 interest
# Images labeled with the  high_boots tag: show 0.1394 amazement
# Images labeled with the  funny_pets tag: show 0.1924 joy
# Images labeled with the  slow_motion tag: show 0.1141 interest
# Images labeled with the  funny_dog tag: show 0.2859 joy
# Images labeled with the  working_group tag: show 0.1234 amazement
# Images labeled with the  old_friends tag: show 0.127 joy

# %%
#verify that each ANP label has the same emotion labels and scores across all images
anp_df[(anp_df.emotion_label=='joy') & (anp_df.anp_label=='young_couple')][:3]
# Out:
#                           image_id     anp_label  anp_sentiment  \
# 1     951727030670259635_143763900  young_couple          0.019
# 1016    956837953127354719_6734387  young_couple          0.019
# 1679  961014334304796262_143854846  young_couple          0.019
#
#       emotion_score emotion_label
# 1            0.2113           joy
# 1016         0.2113           joy
# 1679         0.2113           joy

# %%
anp_df.apply(fill_emotions_matrix ,axis=1)

# %%
#plot some of the lowest emotion scores
anp_df[anp_df.emotion_score == anp_df.emotion_score.min()][::50]
#aparently no one gives a shit about flat lakes, snowy plovers or gold_bridges
# Out:
#                               image_id     anp_label  anp_sentiment  \
# 9612       581742959299903837_21697543     flat_lake         -0.036
# 44932     844465605783354211_187539125  snowy_plover          0.013
# 103220     472461365156868908_25469443  snowy_plover          0.013
# 125497     640658853911311267_55281515     flat_lake         -0.036
# 158622     888102345472019372_11520833  snowy_plover          0.013
# 195058   1347305921630342109_619868570  snowy_plover          0.013
# 206081  1396432770201223841_3807589911  snowy_plover          0.013
# 261877     472461365156868908_25469443  snowy_plover          0.013
# 278568     1016105401709793550_6734387   gold_bridge         -0.004
# 313835     1212399656613744758_6734387   gold_bridge         -0.004
#
#         emotion_score emotion_label
# 9612           0.0417      interest
# 44932          0.0417     vigilance
# 103220         0.0417         anger
# 125497         0.0417       boredom
# 158622         0.0417      loathing
# 195058         0.0417       sadness
# 206081         0.0417   distraction
# 261877         0.0417     amazement
# 278568         0.0417          fear
# 313835         0.0417    acceptance

# %%
# Merge them based on the image_id so that we have a large data frame containing all the elements

image_anp_frame = pd.merge(image_df, anp_df, how='inner', on='image_id')
im_anp_obj_frame = pd.merge(image_anp_frame, object_labels_df, how='inner', on='image_id')
im_anp_obj_face_frame = pd.merge(im_anp_obj_frame, face_df, how='inner', on='image_id')
im_anp_obj_face_frame = pd.merge(im_anp_obj_frame, face_df, how='inner', on='image_id')

# %%
# Calculate the correlation coefficients. Notice how the main diagonal is 1.00

correlation_matrix = im_anp_obj_face_frame.corr()
correlation_matrix
# Out:
#                            image_height  image_width  data_memorability  \
# image_height                   1.000000     0.367477           0.092194
# image_width                    0.367477     1.000000          -0.048363
# data_memorability              0.092194    -0.048363           1.000000
# user_followed_by              -0.044179     0.032737          -0.010293
# user_follows                  -0.110193    -0.051495          -0.046380
# user_posted_photos             0.056780     0.062664          -0.067173
# anp_sentiment                  0.015892    -0.008777           0.106849
# emotion_score                  0.006732    -0.003462           0.055681
# data_amz_label_confidence      0.014332     0.000225           0.032926
# face_id                       -0.034337     0.026916          -0.315009
# face_gender_confidence        -0.008701    -0.009760           0.014746
# face_age_range_high           -0.052446    -0.010250          -0.107471
# face_age_range_low            -0.053418    -0.008285          -0.115616
# face_sunglasses                0.000161     0.001980          -0.032094
# face_beard                    -0.010690     0.027605          -0.063643
# face_beard_confidence          0.010262    -0.015589           0.047527
# face_mustache                 -0.007228     0.031723          -0.037170
# face_mustache_confidence       0.008502    -0.013112           0.044731
# face_smile                     0.000130    -0.018547           0.052936
# face_smile_confidence          0.008904    -0.009949           0.044846
# eyeglasses                     0.004826     0.008953          -0.033755
# eyeglasses_confidence          0.016588     0.003785           0.083209
# emo_confidence                -0.000509    -0.004968          -0.003185
#
#                            user_followed_by  user_follows  user_posted_photos  \
# image_height                      -0.044179     -0.110193            0.056780
# image_width                        0.032737     -0.051495            0.062664
# data_memorability                 -0.010293     -0.046380           -0.067173
# user_followed_by                   1.000000      0.300155            0.150294
# user_follows                       0.300155      1.000000            0.040369
# user_posted_photos                 0.150294      0.040369            1.000000
# anp_sentiment                     -0.011532     -0.017019           -0.054813
# emotion_score                      0.002684      0.003237           -0.050928
# data_amz_label_confidence          0.006521     -0.003662           -0.002424
# face_id                           -0.014647      0.022166            0.024249
# face_gender_confidence             0.006756      0.018167            0.009058
# face_age_range_high                0.084766      0.089671            0.097951
# face_age_range_low                 0.077775      0.086768            0.099524
# face_sunglasses                   -0.011087      0.013937            0.018212
# face_beard                         0.043988      0.004460            0.061977
# face_beard_confidence             -0.028013     -0.005718           -0.010526
# face_mustache                      0.046854     -0.005291            0.064271
# face_mustache_confidence          -0.025272      0.001897           -0.019818
# face_smile                        -0.082719      0.007140           -0.064448
# face_smile_confidence             -0.052183      0.011807           -0.019717
# eyeglasses                        -0.024712      0.010431            0.083662
# eyeglasses_confidence             -0.008538     -0.003827           -0.024243
# emo_confidence                    -0.013778      0.005050           -0.005419
#
#                            anp_sentiment  emotion_score  \
# image_height                    0.015892       0.006732
# image_width                    -0.008777      -0.003462
# data_memorability               0.106849       0.055681
# user_followed_by               -0.011532       0.002684
# user_follows                   -0.017019       0.003237
# user_posted_photos             -0.054813      -0.050928
# anp_sentiment                   1.000000       0.339011
# emotion_score                   0.339011       1.000000
# data_amz_label_confidence       0.005725       0.008191
# face_id                        -0.059100      -0.020458
# face_gender_confidence         -0.005834       0.005323
# face_age_range_high            -0.073432      -0.036045
# face_age_range_low             -0.070340      -0.036649
# face_sunglasses                -0.029941      -0.007838
# face_beard                     -0.031011      -0.029593
# face_beard_confidence           0.020933       0.021920
# face_mustache                  -0.023893      -0.027413
# face_mustache_confidence        0.019850       0.023165
# face_smile                      0.042821       0.039717
# face_smile_confidence           0.030767       0.029398
# eyeglasses                     -0.042127      -0.019903
# eyeglasses_confidence           0.017479       0.015404
# emo_confidence                  0.004419       0.006878
#
#                            data_amz_label_confidence   face_id  \
# image_height                                0.014332 -0.034337
# image_width                                 0.000225  0.026916
# data_memorability                           0.032926 -0.315009
# user_followed_by                            0.006521 -0.014647
# user_follows                               -0.003662  0.022166
# user_posted_photos                         -0.002424  0.024249
# anp_sentiment                               0.005725 -0.059100
# emotion_score                               0.008191 -0.020458
# data_amz_label_confidence                   1.000000 -0.025877
# face_id                                    -0.025877  1.000000
# face_gender_confidence                      0.001213 -0.015206
# face_age_range_high                        -0.011930 -0.009760
# face_age_range_low                         -0.013103  0.000463
# face_sunglasses                            -0.002400  0.036708
# face_beard                                  0.000109  0.013296
# face_beard_confidence                      -0.003093 -0.003710
# face_mustache                              -0.004050  0.005873
# face_mustache_confidence                    0.001187 -0.005058
# face_smile                                  0.002615 -0.023133
# face_smile_confidence                      -0.001492 -0.011505
# eyeglasses                                 -0.004318  0.009042
# eyeglasses_confidence                       0.007987 -0.027795
# emo_confidence                             -0.001657  0.005240
#
#                                 ...        face_sunglasses  face_beard  \
# image_height                    ...               0.000161   -0.010690
# image_width                     ...               0.001980    0.027605
# data_memorability               ...              -0.032094   -0.063643
# user_followed_by                ...              -0.011087    0.043988
# user_follows                    ...               0.013937    0.004460
# user_posted_photos              ...               0.018212    0.061977
# anp_sentiment                   ...              -0.029941   -0.031011
# emotion_score                   ...              -0.007838   -0.029593
# data_amz_label_confidence       ...              -0.002400    0.000109
# face_id                         ...               0.036708    0.013296
# face_gender_confidence          ...              -0.024328    0.001702
# face_age_range_high             ...               0.048594    0.183553
# face_age_range_low              ...               0.039953    0.196486
# face_sunglasses                 ...               1.000000    0.051923
# face_beard                      ...               0.051923    1.000000
# face_beard_confidence           ...              -0.063532   -0.298913
# face_mustache                   ...               0.051011    0.680913
# face_mustache_confidence        ...              -0.072344   -0.334525
# face_smile                      ...              -0.005186   -0.020284
# face_smile_confidence           ...              -0.013613   -0.061589
# eyeglasses                      ...               0.426787    0.110675
# eyeglasses_confidence           ...              -0.012112   -0.082774
# emo_confidence                  ...               0.002374   -0.033928
#
#                            face_beard_confidence  face_mustache  \
# image_height                            0.010262      -0.007228
# image_width                            -0.015589       0.031723
# data_memorability                       0.047527      -0.037170
# user_followed_by                       -0.028013       0.046854
# user_follows                           -0.005718      -0.005291
# user_posted_photos                     -0.010526       0.064271
# anp_sentiment                           0.020933      -0.023893
# emotion_score                           0.021920      -0.027413
# data_amz_label_confidence              -0.003093      -0.004050
# face_id                                -0.003710       0.005873
# face_gender_confidence                  0.007847       0.001170
# face_age_range_high                    -0.091187       0.170000
# face_age_range_low                     -0.091217       0.182792
# face_sunglasses                        -0.063532       0.051011
# face_beard                             -0.298913       0.680913
# face_beard_confidence                   1.000000      -0.193155
# face_mustache                          -0.193155       1.000000
# face_mustache_confidence                0.429438      -0.324081
# face_smile                              0.043524      -0.017414
# face_smile_confidence                   0.060583      -0.057879
# eyeglasses                             -0.072350       0.089051
# eyeglasses_confidence                   0.066496      -0.056019
# emo_confidence                          0.020794      -0.029996
#
#                            face_mustache_confidence  face_smile  \
# image_height                               0.008502    0.000130
# image_width                               -0.013112   -0.018547
# data_memorability                          0.044731    0.052936
# user_followed_by                          -0.025272   -0.082719
# user_follows                               0.001897    0.007140
# user_posted_photos                        -0.019818   -0.064448
# anp_sentiment                              0.019850    0.042821
# emotion_score                              0.023165    0.039717
# data_amz_label_confidence                  0.001187    0.002615
# face_id                                   -0.005058   -0.023133
# face_gender_confidence                     0.015422    0.031535
# face_age_range_high                       -0.093795   -0.012787
# face_age_range_low                        -0.096365   -0.015908
# face_sunglasses                           -0.072344   -0.005186
# face_beard                                -0.334525   -0.020284
# face_beard_confidence                      0.429438    0.043524
# face_mustache                             -0.324081   -0.017414
# face_mustache_confidence                   1.000000    0.042795
# face_smile                                 0.042795    1.000000
# face_smile_confidence                      0.056200    0.194081
# eyeglasses                                -0.066166   -0.005535
# eyeglasses_confidence                      0.060187    0.029517
# emo_confidence                             0.020492    0.077528
#
#                            face_smile_confidence  eyeglasses  \
# image_height                            0.008904    0.004826
# image_width                            -0.009949    0.008953
# data_memorability                       0.044846   -0.033755
# user_followed_by                       -0.052183   -0.024712
# user_follows                            0.011807    0.010431
# user_posted_photos                     -0.019717    0.083662
# anp_sentiment                           0.030767   -0.042127
# emotion_score                           0.029398   -0.019903
# data_amz_label_confidence              -0.001492   -0.004318
# face_id                                -0.011505    0.009042
# face_gender_confidence                  0.020220   -0.017012
# face_age_range_high                    -0.019397    0.108730
# face_age_range_low                     -0.021028    0.104830
# face_sunglasses                        -0.013613    0.426787
# face_beard                             -0.061589    0.110675
# face_beard_confidence                   0.060583   -0.072350
# face_mustache                          -0.057879    0.089051
# face_mustache_confidence                0.056200   -0.066166
# face_smile                              0.194081   -0.005535
# face_smile_confidence                   1.000000   -0.036652
# eyeglasses                             -0.036652    1.000000
# eyeglasses_confidence                   0.035847   -0.166852
# emo_confidence                          0.060597   -0.009750
#
#                            eyeglasses_confidence  emo_confidence
# image_height                            0.016588       -0.000509
# image_width                             0.003785       -0.004968
# data_memorability                       0.083209       -0.003185
# user_followed_by                       -0.008538       -0.013778
# user_follows                           -0.003827        0.005050
# user_posted_photos                     -0.024243       -0.005419
# anp_sentiment                           0.017479        0.004419
# emotion_score                           0.015404        0.006878
# data_amz_label_confidence               0.007987       -0.001657
# face_id                                -0.027795        0.005240
# face_gender_confidence                  0.012206        0.004159
# face_age_range_high                    -0.019763       -0.004199
# face_age_range_low                     -0.025025       -0.006367
# face_sunglasses                        -0.012112        0.002374
# face_beard                             -0.082774       -0.033928
# face_beard_confidence                   0.066496        0.020794
# face_mustache                          -0.056019       -0.029996
# face_mustache_confidence                0.060187        0.020492
# face_smile                              0.029517        0.077528
# face_smile_confidence                   0.035847        0.060597
# eyeglasses                             -0.166852       -0.009750
# eyeglasses_confidence                   1.000000        0.010283
# emo_confidence                          0.010283        1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# ** To-Do 3: Plot the correlation matrix with color codes corresponding to the how much two attributes are correlated. **
#
# ** To-Do 4: Calculate the Spearman rank for the attributes. **

# %% [markdown]
# ### ASSIGNMENT
#
# In this notebook we learned how to train and test a regressor on numerical data. For this assignment you are required to do the following:
#
# 1. Split the data into training and testing splits
# 2. Train a regressor to predict the PERMA scores on the test set using different sets of attributes (not all of them at once)
# 3. Analyze which features (attributes) correlate well with each other and help in fitting the curve to the data better.
# 4. Elaborate on the results.
